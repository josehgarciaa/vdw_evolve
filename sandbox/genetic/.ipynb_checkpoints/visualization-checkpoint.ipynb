# %%
import numpy as np
import matplotlib.pyplot as plt
from genetic_one import Gen1

# %%
def function_a(x):
    x=x[0]
    return x*x+3*x-5+np.sqrt(np.sqrt(x**2))+5*np.sin(x-5)*2*x

a = 50
X =[i for i in range(-a,a)]
Y =[function_a([x]) for x in X]

# %%
# Experiment settings

#Hyperparameters of the model
model_par = {
    
    'cell_split_number': 5, 
    'subjects_in_cell': 1,

    'nr_clones': 5,
    'mutation_gaussian_sd': 4,

    'pins': 5,
    'gene_quality': 1,
    
}

#
input_size = 1 # since our function has one variable this is a trivial scenario.
bounds =[[-a,a]] # searching intervals for the solution

# Experiment
experiment = Gen1(function_a ,input_size, bounds, model_par)

# %%
# first generation
# 'cell_split_number': 5 and  'subjects_in_cell': 2,
#  we expect 10 possible solutions.

gen_0 = experiment.first_generation()
experiment.actual_generation = gen_0

print("gen_0", gen_0)
plt.scatter(gen_0,[function_a(x) for x in gen_0] , c='r')
plt.plot(X,Y)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# gen_0 [[-45], [-30], [1], [14], [46]]

# %%
## Automate evolution

nr_epochs = 4
last_generation, history= experiment.evolve(nr_epochs,history=True)
fit = [function_a(x) for x in last_generation] 
plt.scatter(last_generation, fit , c='b', label='generation', alpha=0.3)
plt.plot(X,Y)
plt.legend()
# Out:
# Epochs 0/4
# Evolution process ended!
# Last generation: [[-4], [-12], [-24], [-24], [2], [-10], [-10], [-18], [-18], [-30]]
# Epochs 1/4
# Evolution process ended!
# Last generation: [[-12], [-6], [-2], [-2], [-18], [-15], [-15], [-8], [-8], [-5]]
# Epochs 2/4
# Evolution process ended!
# Last generation: [[-6], [-10], [-7], [-7], [-8], [-6], [-6], [-10], [-10], [-7]]
# Epochs 3/4
# Evolution process ended!
# Last generation: [[-6], [-6], [-6], [-6], [-6], [-6], [-6], [-6], [-6], [-6]]

# %%
colour=[]
step=0.25

time = 0
Y0=[ time for _ in X]
time+=1
plt.scatter(Y0,X, c='b', label='base', alpha=0.1)

gen_0 = history[0]['gen_0']
Y0=[time for _ in gen_0]
colours =[]
time=time+1
plt.scatter(Y0,gen_0, c='r', label='generation_0', alpha=0.1)

cf = history[0]['clone_family']
clone_family =[]
for f in cf:
    for c in f:
        clone_family.append(c)

Y0=[time for _ in clone_family]
colours =[]
time=time+1
plt.scatter(Y0,clone_family, c='r', label='clone',marker='^', alpha=0.2)


survivours= history[0]['generation']
Y0=[time for _ in survivours]
colours =[]
time=time+1
plt.scatter(Y0,survivours, c='g', label='survivours',marker='*', alpha=0.2)

new_generation= history[0]['new_generation']
Y0=[time for _ in new_generation]
colours =[]
time=time+1
plt.scatter(Y0,new_generation, c='g', label='new_generation',marker='o', alpha=0.2)


plt.legend()
