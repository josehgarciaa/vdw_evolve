# %%
import numpy as np
from numpy.linalg import inv, det


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import sys
 
# setting path
sys.path.append('/Users/voicutu/Documents/GitHub/vdw_evolve/sandbox/vdw')
from anneling import GradientAnnealing
from anneling.hook import discrete_hook

import random
random.seed(99)

# %%
COUNTER = 0

# %%
def xyz_gen(gen, function):
    
    x=[x[0] for x in gen]
    y=[x[1] for x in gen]
    z=[function([x[i],y[i]],count=False) for i in range(len(gen))]
    return x,y,z

# %%
N1 = 100
N2 = 100
grid_dim = 20
Ef = 1
EfI=  Ef*np.array([[1,0],[0,1]])
piI = 2*np.pi* np.array([[1,0],[0,1]])

A = np.array([ [1/2, np.sqrt(3)/2],
               [1/2, -np.sqrt(3)/2]]).T
invA= inv(A)
B = 2*np.pi*invA.T

def H_mat(n1,n2):
    
    k = (n1/N1)*B[:,0]+(n2/N2)*B[:,1]
    
    ka1=np.dot(A[:,0],k) # ka1,k2 = np.dot(A,k)
    ka2=np.dot(A[:,1],k)
    
    f = np.exp(1j*ka1)+ np.exp(1j*ka2)+1 
    
    f_conj= np.conj(f)
    
    H = np.array([[0, f],[f_conj,0]])
    
    return H

def det_sq(n1,n2):
    
    det_H= det( H_mat(n1,n2)-EfI )

    return np.real(det_H)*np.real(det_H)

def bands_F(n1,n2):
    
    bands= np.linalg.eigvals( H_mat(n1,n2) )

    return np.real(bands)

# %%
X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
bands= np.transpose([[ bands_F(x1,x2) for x2 in X2] for x1 in X1], axes=[2,1,0])
print(bands.shape)  

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

for band in bands:

    surf = ax.plot_surface(X1, X2, band, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
    

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# (2, 100, 100)

# %%
def fit_function(x, count=True):
    if count:
        global COUNTER
        COUNTER+=1
    return det_sq(x[0],x[1])

X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
Z= np.array([fit_function([x1,x2]) for x2 in X2 for x1 in X1])
print("zsort:",np.sort(Z)[:5]) 

Z= np.array([[fit_function([x1,x2]) for x2 in X2] for x1 in X1])

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X1, X2, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# zsort: [0. 0. 0. 0. 0.]

# %%
# Experiment settings

#Hyperparameters of the model
model_par = {
    
    'initialTemp': 1, 
    'finalTemp': 0.0003,

    'beta': 10,
    'bounds': [[-N1,N1],[-N2,N2]],

    'nr_neighbours': 1,
    'gaussian_sd':5,
    
    'gradient_influence':0.45,
    'delta_p': 0.2,
    'g_step_size':7,
    'step_size': 4,
    
    
    
    'known_min': 8.76763323079435e-05
    
}

#
input_size = 2 # since our function has one variable this is a trivial scenario.
start_point = [20, 30]

# Experiment
experiment = GradientAnnealing(fit_function,start_point, model_par)

# %%
epochs= 5
history_book = experiment.evolve( epochs, prints_p=5)
# Out:
# temp:1|epoch:0|change:-4.374202314825405|value:8.715967628924076
# temp:0.09090909090909091|epoch:0|change:6.027392255014414|value:1.783628792163729
# temp:0.047619047619047616|epoch:0|change:0.777376041414978|value:0.014674629441242017
# temp:0.03225806451612903|epoch:0|change:0.007658603416361258|value:0.05324695047563756
# temp:0.024390243902439025|epoch:0|change:0.0698495605324786|value:0.0009831186132424853

# %%
final_solution = experiment.actual_solution
final_value = fit_function(experiment.actual_solution)
print("final_solution:",final_solution)
print("final_value:",final_value)
# Out:
# final_solution: [7, 57]
# final_value: 0.0

# %%
COUNTER = 0
solutions = []
solution_values=[]
for s1 in range(-N1,N1 ,grid_dim):
    for s2 in range(-N2+20,N2-20, grid_dim):
        start_point =[s1,s2]
        experiment = GradientAnnealing(fit_function,start_point, model_par)
        experiment.evolve( epochs, prints_p=999, tr_print=False)
        solutions.append(experiment.actual_solution)
        solution_values.append(experiment.actual_value)
        print("start points:{} |solution:{} |value:{}".format(start_point,experiment.actual_solution,experiment.actual_value))
# Out:
# start points:[-100, -80] |solution:[-85, -50] |value:5.997362516627134e-32
# start points:[-100, -60] |solution:[-88, -50] |value:2.462758083818294e-32
# start points:[-100, -40] |solution:[-80, -30] |value:1.972152263052519e-31
# start points:[-100, -20] |solution:[-59, -50] |value:2.4397116215366817e-31
# start points:[-100, 0] |solution:[-63, -13] |value:4.930380657631348e-32
# start points:[-100, 20] |solution:[-82, 68] |value:4.437342591868193e-31
# start points:[-100, 40] |solution:[-99, 50] |value:1.2471220487611516e-32
# start points:[-100, 60] |solution:[-73, 50] |value:4.506668351169059e-31
# start points:[-80, -80] |solution:[-47, -97] |value:0.0
# start points:[-80, -60] |solution:[-49, -51] |value:6.205518088060036e-05
# start points:[-80, -40] |solution:[-80, -50] |value:1.1148927997990759e-32
# start points:[-80, -20] |solution:[-78, -50] |value:4.558116681128296e-31
# start points:[-80, 0] |solution:[-78, -28] |value:4.930380657631348e-32
# start points:[-80, 20] |solution:[-78, 72] |value:4.437342591868193e-31
# start points:[-80, 40] |solution:[-73, 50] |value:4.506668351169059e-31
# start points:[-80, 60] |solution:[-50, 97] |value:1.1749127667337771e-31
# start points:[-60, -80] |solution:[-50, -95] |value:1.506569020794234e-32
# start points:[-60, -60] |solution:[-90, -50] |value:0.0
# start points:[-60, -40] |solution:[-51, -49] |value:6.205518088060036e-05
# start points:[-60, -20] |solution:[-62, -50] |value:0.0
# start points:[-60, 0] |solution:[-50, -3] |value:0.0
# start points:[-60, 20] |solution:[-50, 35] |value:1.599770667950059e-31
# start points:[-60, 40] |solution:[-50, 49] |value:1.2471220487611516e-32
# start points:[-60, 60] |solution:[-49, 49] |value:6.205518088060036e-05
# start points:[-40, -80] |solution:[-50, -89] |value:2.4433576797154823e-32
# start points:[-40, -60] |solution:[-50, -49] |value:1.2471220487611516e-32
# start points:[-40, -40] |solution:[-3, -50] |value:0.0
# start points:[-40, -20] |solution:[-49, -50] |value:1.2471220487611516e-32
# start points:[-40, 0] |solution:[-50, -15] |value:2.4048628274718025e-32
# start points:[-40, 20] |solution:[-35, 50] |value:1.599770667950059e-31
# start points:[-40, 40] |solution:[-16, 50] |value:9.391522455611415e-32
# start points:[-40, 60] |solution:[-50, 58] |value:2.4614412887971936e-31
# start points:[-20, -80] |solution:[2, -50] |value:0.0
# start points:[-20, -60] |solution:[7, -50] |value:0.0
# start points:[-20, -40] |solution:[-14, -50] |value:5.849460895023011e-32
# start points:[-20, -20] |solution:[-51, -49] |value:6.205518088060036e-05
# start points:[-20, 0] |solution:[-52, -2] |value:0.0
# start points:[-20, 20] |solution:[-10, 50] |value:0.0
# start points:[-20, 40] |solution:[-51, 51] |value:6.205518088060036e-05
# start points:[-20, 60] |solution:[-21, 50] |value:2.158996090622489e-31
# start points:[0, -80] |solution:[-25, -75] |value:4.930380657631348e-32
# start points:[0, -60] |solution:[-13, -63] |value:4.930380657631348e-32
# start points:[0, -40] |solution:[-2, -50] |value:1.2910766632748516e-32
# start points:[0, -20] |solution:[13, -37] |value:1.2325951644078266e-30
# start points:[0, 0] |solution:[22, -28] |value:2.4158865222393357e-30
# start points:[0, 20] |solution:[-30, 50] |value:6.52435742841926e-31
# start points:[0, 40] |solution:[18, 68] |value:1.774937036747284e-30
# start points:[0, 60] |solution:[21, 50] |value:2.0326114513934333e-31
# start points:[20, -80] |solution:[50, -37] |value:0.0
# start points:[20, -60] |solution:[1, -49] |value:0.0
# start points:[20, -40] |solution:[-9, -50] |value:9.391522455611415e-32
# start points:[20, -20] |solution:[3, -47] |value:1.1093356479670443e-31
# start points:[20, 0] |solution:[39, -11] |value:7.888609052210104e-31
# start points:[20, 20] |solution:[50, 55] |value:0.0
# start points:[20, 40] |solution:[6, 56] |value:1.972152263052519e-31
# start points:[20, 60] |solution:[43, 50] |value:1.5398695741243803e-32
# start points:[40, -80] |solution:[50, -69] |value:2.788726864500923e-30
# start points:[40, -60] |solution:[50, -58] |value:2.4614412887971936e-31
# start points:[40, -40] |solution:[32, -18] |value:4.437342591868193e-31
# start points:[40, -20] |solution:[50, -61] |value:2.443357679715483e-32
# start points:[40, 0] |solution:[50, 9] |value:9.391522455611415e-32
# start points:[40, 20] |solution:[50, 32] |value:1.5398695741243798e-32
# start points:[40, 40] |solution:[38, 50] |value:0.0
# start points:[40, 60] |solution:[37, 87] |value:4.930380657631348e-32
# start points:[60, -80] |solution:[67, -50] |value:6.153603221993047e-32
# start points:[60, -60] |solution:[50, -79] |value:5.559044395624948e-32
# start points:[60, -40] |solution:[50, -32] |value:1.539869574124381e-32
# start points:[60, -20] |solution:[50, -25] |value:4.930380657631348e-32
# start points:[60, 0] |solution:[54, 4] |value:0.0
# start points:[60, 20] |solution:[50, 47] |value:1.3054586297041844e-32
# start points:[60, 40] |solution:[50, 9] |value:9.391522455611415e-32
# start points:[60, 60] |solution:[52, 50] |value:2.002963711630682e-31
# start points:[80, -80] |solution:[70, -80] |value:4.437342591868193e-31
# start points:[80, -60] |solution:[97, -50] |value:1.1749127667337771e-31
# start points:[80, -40] |solution:[76, -50] |value:4.4546752013795825e-31
# start points:[80, -20] |solution:[61, -50] |value:2.443357679715483e-32
# start points:[80, 0] |solution:[55, 5] |value:0.0
# start points:[80, 20] |solution:[50, -2] |value:0.0
# start points:[80, 40] |solution:[100, 50] |value:0.0
# start points:[80, 60] |solution:[94, 50] |value:5.206064731359554e-31

# %%
print("Cout :", COUNTER)
print("Advantage:", COUNTER/(4*N1*N2))
# Out:
# Cout : 9287
# Advantage: 0.232175

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_493/4267174279.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# Clen the results
tollerance = model_par['known_min']
clean_solutions=[]
for i in range(len(solutions)):
    if solution_values[i] <= tollerance:
        clean_solutions.append(solutions[i])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(clean_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_493/3868486351.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
print("Cout :", COUNTER)
# Out:
# Cout : 9287

# %%
# now we need to be sure that we extract a complet contour

explored = []

total_solutions = []
total_values = []
for solution in clean_solutions:
    if solution not in explored:
        explored.append(solution)
        
        extend_solutions, extended_values = discrete_hook(fit_function,solution,boundary=[[-N1,N1],[N2,N2]],tolerance =0.02)
        print("extended_solutions:",extend_solutions)
        for i in range(len(extend_solutions)):
            s=extend_solutions[i]
            v= extended_values[i]
            total_solutions.append(s)
            total_values.append(v)
            explored.append(solution)

# %%
print("Final Cout :", COUNTER)
print("Final Advantage:", COUNTER/(4*N1*N2))

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(total_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')

# %%
#final selection
f_select =[]
v_select =[]
minim = 8.76763323079435e-05

for i in range(len(total_solutions)):
    s = total_solutions[i]
    v = total_values[i]
    if v<=minim:
        if s not in f_select:
            f_select.append(s)
            v_select.append(v)
    
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(f_select, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
