# %%
import matplotlib.pyplot as plt
import numpy as np
import ase.db
import pandas as pd

def dbelem2array(x):
    shape, dtype, arr  = x['__ndarray__'];
    return np.array(arr, dtype=dtype).reshape(shape);    


# Connect to database
db = ase.db.connect('c2db.db')

options = 'is_magnetic=True, thermodynamic_stability_level=3'

rows = db.select(options)
print("The number of elements is:",len(list(rows)) )

props = ["formula","spgnum", "spacegroup", "dE_zx", "dE_zy", "lam","magmom", "magstate", "doi","uid"] 
rows = db.select(options)
data = [ [ x.get(p) for p in props ] for x in rows ]
raw_df = pd.DataFrame( data, columns = props);
raw_df = raw_df[ (raw_df["spacegroup"]!='P1') & (raw_df["spacegroup"]!='Pc')& (raw_df["spacegroup"]!='P-1') ];

print( raw_df[["formula","uid"]] )
# Out:
# The number of elements is: 402
#        formula                     uid
# 0       Mn2Se2     Mn2Se2-a1d595c25fc5
# 1        Ru2F8      Ru2F8-5b1d25d726e0
# 2         V2F8       V2F8-6d78fbe605b3
# 3     Bi2MnTe4   MnBi2Te4-a8bb2517b2b7
# 4      CrGa2S4    CrGa2S4-e6aae0f0d940
# ..         ...                     ...
# 394     Cr2Cl6     Cr2Cl6-9f9e75488d50
# 395     Pt2Cl6     Pt2Cl6-20b975a3a1e8
# 396    V2Br2N2    Br2N2V2-186b2da4920f
# 397  Mn2Cl2Se2  Cl2Mn2Se2-6bdadd86e6c4
# 400       VSSe       SSeV-0f3ba3ea815f
#
# [337 rows x 2 columns]

# %% [markdown]
# Let's first evalute their separation in terms of spacegroup

# %%
spacegroups = raw_df["spacegroup"].unique();
spg2idx = dict(zip(spacegroups,np.arange(len(spacegroups)) ));
indexes = np.array([spg2idx[spg] for spg in raw_df["spacegroup"] ]);
counts  = pd.cut( indexes , bins=len(spacegroups)).value_counts().values;

sarg = np.argsort(counts)[::-1]
spacegroups = spacegroups[sarg];
print(spacegroups)
indexes = indexes[sarg];
counts = counts[sarg]
plt.plot( counts[:10], 'o')

print("The first 10 elements represents the ",100*np.sum(np.sort(- counts)[:10])/ np.sum(counts), "percent" )
# Out:
# ['P-3m1' 'P-31m' 'Pmmn' 'P-6m2' 'P3m1' 'C2/m' 'P-62m' 'P-4m2' 'P4/nmm'
#  'P-3' 'C2' 'P2_1/m' 'P2_1/c' 'P2/m' 'Cm' 'Pmm2' 'Pmmm' 'P2_1' 'P4/mmm'
#  'Amm2' 'Pmma' 'Pmn2_1' 'P2/c' 'P321' 'Pmc2_1' 'P4/n' 'P4mm' 'Pm' 'P3']
# The first 10 elements represents the  -77.74480712166172 percent

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = spacegroups[:10];
sizes = 100*counts[:10]/ np.sum(counts)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, startangle=90,  wedgeprops=dict(width=0.5, edgecolor='k'),)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

fig= plt.gcf();
fig.savefig("pieplot.pdf")
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = spacegroups[:10];
sizes = 100*counts[:10]/ np.sum(counts)

x = np.arange(len(labels))  # the label locations
width = 0.7 # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x , sizes, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of materials')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.ylim(0,25)


fig.tight_layout()

fig= plt.gcf();
fig.savefig("barplot.pdf")
plt.show()

# %%
raw_df[raw_df.spacegroup == 'P-4m2']
# Out:
#     formula  spgnum spacegroup     dE_zx     dE_zy       lam    magmom  \
# 80    CoBr2     115      P-4m2 -0.068329 -0.068306  0.001689  2.999999
# 81    MnBr2     115      P-4m2 -0.176210 -0.176171  0.005501  5.000000
# 109   CoCl2     115      P-4m2 -0.145808 -0.145821 -0.004060  3.000000
# 113    NiI2     115      P-4m2 -4.912737 -4.912205  3.421658  1.773452
# 170   MnCl2     115      P-4m2 -0.047969 -0.047974  0.001443  5.000000
# 198  Ni2Te2     115      P-4m2 -0.471322 -0.468948  0.194427  1.034241
# 200    CoF2     115      P-4m2  0.395881  0.395880 -0.014265  3.000000
# 227   FeBr2     115      P-4m2  0.958399  0.958245 -0.016233  4.000000
# 253   FeCl2     115      P-4m2  1.401151  1.401150  0.024873  4.000000
# 258     VO2     115      P-4m2 -0.007118 -0.007123  0.029152  0.999520
# 282    CoI2     115      P-4m2  1.160045  1.159726 -0.091530  2.999713
# 313    MnI2     115      P-4m2 -0.364194 -0.364019  0.022367  5.000000
# 314   NiBr2     115      P-4m2  0.349519  0.349306 -0.123485  1.998953
# 345   Ni2S2     115      P-4m2  0.039584  0.039597 -0.021376  0.964194
# 365    CrI2     115      P-4m2  1.886794  1.888536  0.017012  4.000000
# 390    FeI2     115      P-4m2 -0.200233 -0.200382       NaN  4.000000
#
#     magstate   doi                  uid
# 80        FM  None   CoBr2-807b6a88f950
# 81        FM  None   MnBr2-6e4f4724ab75
# 109       FM  None   CoCl2-2f828537d676
# 113       FM  None    NiI2-15ccde3e8d83
# 170       FM  None   MnCl2-8eec64049548
# 198       FM  None  Ni2Te2-725232091cb8
# 200       FM  None    CoF2-2f2f01730826
# 227       FM  None   FeBr2-d7c6901921a7
# 253       FM  None   FeCl2-0af1baed7940
# 258       FM  None     VO2-23bb81344202
# 282       FM  None    CoI2-b8ec8fbbcdc2
# 313       FM  None    MnI2-c37f0a810838
# 314       FM  None   NiBr2-7937431cc8b7
# 345       FM  None   Ni2S2-45c8c6156f9b
# 365       FM  None    CrI2-53a7a202e7c7
# 390       FM  None    FeI2-51934c0239e8

# %% [markdown]
# # Get the data from the database

# %%
import wget
import os.path


for uid in raw_df.uid:
    dataurl = 'https://cmrdb.fysik.dtu.dk/c2db/row/'+uid+'/all_data';
    file = "data/"+uid+"_data.json"
    if os.path.isfile(file):
        print("file: ",file, "found")
    else:
        print(wget.download(dataurl, out='./data'))
# Out:
# file:  data/Mn2Se2-a1d595c25fc5_data.json found
# file:  data/Ru2F8-5b1d25d726e0_data.json found
# file:  data/V2F8-6d78fbe605b3_data.json found
# file:  data/MnBi2Te4-a8bb2517b2b7_data.json found
# file:  data/CrGa2S4-e6aae0f0d940_data.json found
# file:  data/F2N3V4-3f5b11d43a1b_data.json found
# file:  data/N3Sc4-daf440ed0646_data.json found
# file:  data/FeI2-958162d78580_data.json found
# file:  data/VCl2-1ccb0b28392d_data.json found
# file:  data/VS2-c18868e1945f_data.json found
# file:  data/NMn2O2-540070b9d266_data.json found
# file:  data/GaBr2Ni5-31ea063f0612_data.json found
# file:  data/Ag2Cl6-f753db8ae919_data.json found
# file:  data/Cr2I6-462e253dd5f0_data.json found
# file:  data/Ni2Cl6-60147a25e3e9_data.json found
# file:  data/Zr2Br6-7f49d473708d_data.json found
# file:  data/As2Fe2Li2-99ebdf77e5a2_data.json found
# file:  data/I2N2V2-0a821d6fb09b_data.json found
# file:  data/Li2Mn2P2-32e0950b0bbb_data.json found
# file:  data/SSeV-18612ec43eba_data.json found
# file:  data/Fe3Se4-5d597a885095_data.json found
# file:  data/MnGa2S4-5b314402873d_data.json found
# file:  data/CoCl2N2C4H4-6bda56f4af9b_data.json found
# file:  data/H2O2N3Mn4-0575209d5cde_data.json found
# file:  data/O2N3Cr4-fcc3312d9464_data.json found
# file:  data/Mn2Se2-4e18fc666b1d_data.json found
# file:  data/Ni2Se2-3c97e1d4a4f8_data.json found
# file:  data/CoBr2-019c8b088db5_data.json found
# file:  data/MnBr2-2afc82f66833_data.json found
# file:  data/RhI2-1f1223669a03_data.json found
# file:  data/ScI2-d71a8b9a636e_data.json found
# file:  data/TiI2-d49f2853b897_data.json found
# file:  data/YI2-ed68c71a1964_data.json found
# file:  data/MnH2O2-3bd136c8a265_data.json found
# file:  data/Cr2Te6-e31ef1fbdf8c_data.json found
# file:  data/Ni2I6-58d94153e8e9_data.json found
# file:  data/Pt2I6-262ec9b49ee4_data.json found
# file:  data/Ta2Cl6-d146498193c2_data.json found
# file:  data/V2Te6-e4aaabbabad9_data.json found
# file:  data/Zr2Br6-e33da2247ac2_data.json found
# file:  data/BrCrI-42f0a6cc97b5_data.json found
# file:  data/Fe2Li2Sb2-b39e73a8e6ef_data.json found
# file:  data/NiZrBr6-58bbdebe3477_data.json found
# file:  data/Cr2F4-ebdf3d77e0b6_data.json found
# file:  data/Cu4F4H4O4-bacf5e5a05ad_data.json found
# file:  data/CoN2C4O4H8-57cd5ea00a4e_data.json found
# file:  data/Mn2Te2-070ecae01ad4_data.json found
# file:  data/CoBr2-02049cf3cf55_data.json found
# file:  data/CrO2-a90a10c37b69_data.json found
# file:  data/CrTe2-3fb486362f1a_data.json found
# file:  data/FeTe2-55863d5a82d9_data.json found
# file:  data/MnBr2-4d6ea02f2407_data.json found
# file:  data/MnS2-97234046352a_data.json found
# file:  data/Au2Br6-dbc278a06722_data.json found
# file:  data/Cu2Br6-52732688def7_data.json found
# file:  data/Mn2Br6-6f33dda6bf52_data.json found
# file:  data/Ta2I6-b29f05bd4cc6_data.json found
# file:  data/Zr2Cl6-953c899ee7d7_data.json found
# file:  data/Cr2P2S6-8de594e663b3_data.json found
# file:  data/NiZrCl6-fb1017d33c02_data.json found
# file:  data/Cr2Se2-d68d8b406596_data.json found
# file:  data/Mo2Cl6-086e8348b60a_data.json found
# file:  data/Cu2Ge2O6-95ec7dec91a8_data.json found
# file:  data/F2Fe2O2-6cb0c6e1eb29_data.json found
# file:  data/O2N3Mn4-24ea907e3c1d_data.json found
# file:  data/Br2Sc2-d62ee63a9db1_data.json found
# file:  data/Fe2Te2-b49eca087529_data.json found
# file:  data/CoBr2-807b6a88f950_data.json found
# file:  data/MnBr2-6e4f4724ab75_data.json found
# file:  data/MnS2-a1fb52b45531_data.json found
# file:  data/NiI2-0e87e38a2099_data.json found
# file:  data/Tl2Br4-194d138edf5e_data.json found
# file:  data/NCr2F2-c82f6907a3bd_data.json found
# file:  data/NH2Mn2O2-af38ffeefb90_data.json found
# file:  data/GaCl2Ni5-39e741e94b38_data.json found
# file:  data/Au2Cl6-1fee35476d21_data.json found
# file:  data/Cu2Br6-d725eac1ffd0_data.json found
# file:  data/Mn2Cl6-5d0554fdd87b_data.json found
# file:  data/Nb2Br6-b36d443f19c6_data.json found
# file:  data/Zr2Cl6-a1c0918fe7f5_data.json found
# file:  data/Br2Cr2N2-346d78db9c71_data.json found
# file:  data/ClCrI-56cff5bf2f4a_data.json found
# file:  data/NbSTe-102587cb1e02_data.json found
# file:  data/Cr2P2Se6-2897f2d181b7_data.json found
# file:  data/Ag2F4-8e332582f342_data.json found
# file:  data/Cr3Te4-3d365d19d9c9_data.json found
# file:  data/Cl2Sc2-ee749f75da46_data.json found
# file:  data/Fe2Ga2S5-7f3687eb77ed_data.json found
# file:  data/Li2V4O10-32e7623d80f4_data.json found
# file:  data/Ag2Cr2P4S12-c3bdd3a464e2_data.json found
# file:  data/Co2Se2H4O8-ccb0781e5656_data.json found
# file:  data/NiN2C4O4H8-0401ea22934d_data.json found
# file:  data/Fe2Te2-c0f22a048784_data.json found
# file:  data/CoCl2-2f828537d676_data.json found
# file:  data/FeTe2-d98b0a15009e_data.json found
# file:  data/MnCl2-36192c4a6b20_data.json found
# file:  data/Mn2Se4-47943bd9c080_data.json found
# file:  data/NiI2-15ccde3e8d83_data.json found
# file:  data/VSe2-8535e643c6c5_data.json found
# file:  data/CuH2O2-c14e71e7797d_data.json found
# file:  data/Co2Br6-26f91951e231_data.json found
# file:  data/Cu2Cl6-28fbb0f1e271_data.json found
# file:  data/Mn2Cl6-eb1a0a07e5b5_data.json found
# file:  data/Nb2Cl6-ca5dfc8256fa_data.json found
# file:  data/Ru2Br6-3d38b5c4e340_data.json found
# file:  data/Zr2I6-7442c0cb7793_data.json found
# file:  data/Br2Cr2S2-806bd2cbdf65_data.json found
# file:  data/SeTeV-716e51e45afe_data.json found
# file:  data/NiZrI6-6664877fdd91_data.json found
# file:  data/V3Te6-76d2970ca725_data.json found
# file:  data/MnAl2S4-e9f09f2a4037_data.json found
# file:  data/Ca2Mn2Si2-7ff0ce39e113_data.json found
# file:  data/CuLi2O2-d2b18192bc5f_data.json found
# file:  data/Fe2Ta2Te6-9c5e30777872_data.json found
# file:  data/Br2O2V2-c35a3888dc02_data.json found
# file:  data/Cl2Fe2Mo2O8-8fcb8d9c0b1e_data.json found
# file:  data/NiCl2N2H4C6-368c7a17226f_data.json found
# file:  data/Ni2Te2-17e9890eeaec_data.json found
# file:  data/AgBr2-96cefa3a17db_data.json found
# file:  data/CoCl2-cb7655063dfe_data.json found
# file:  data/CrBr2-8e3c29615618_data.json found
# file:  data/CsF2-0f4680d4a768_data.json found
# file:  data/FeO2-e25173381887_data.json found
# file:  data/MnCl2-81a2afdb71c1_data.json found
# file:  data/MnSe2-26f87ca48216_data.json found
# file:  data/PdBr2-724e74d0941a_data.json found
# file:  data/TiBr2-db38ba041c3b_data.json found
# file:  data/NF2Mn2-b8d6382af747_data.json found
# file:  data/Mn2I6-2033b3b9502c_data.json found
# file:  data/Re2Br6-601836adaccc_data.json found
# file:  data/Zr2I6-c24a780cd241_data.json found
# file:  data/BrClTi-e0e6e981b2fe_data.json found
# file:  data/Br2Cr2Se2-6d18e7a36c5a_data.json found
# file:  data/Br2Ni2O2-167d9b35425e_data.json found
# file:  data/Cl2Cr2N2-6f3c7a9a7189_data.json found
# file:  data/SeTeV-dd97df500ccd_data.json found
# file:  data/Br2Cr2O2-40d95997a4f9_data.json found
# file:  data/GeTe2Fe3-38cc35ba8ee5_data.json found
# file:  data/Mn2Se2O8-59ae1b9f5e1a_data.json found
# file:  data/OVBr2-9da5f3d0e8be_data.json found
# file:  data/Br2Fe2Sr4O6-507e67d24154_data.json found
# file:  data/AgBr2-ff1eda26cff0_data.json found
# file:  data/CoCl2-f4044a1ceaa1_data.json found
# file:  data/FeBr2-8a7a18d48fc2_data.json found
# file:  data/MnCl2-8eec64049548_data.json found
# file:  data/VI2-d480b343c982_data.json found
# file:  data/VSe2-9ec753a2a759_data.json found
# file:  data/YBr2-32aac6e20434_data.json found
# file:  data/AlBr2Ni5-5e8218e1336f_data.json found
# file:  data/Hf2Br6-377d56c4922a_data.json found
# file:  data/Mn2Te6-161b37c77fc8_data.json found
# file:  data/Nb2I6-2debeb910d58_data.json found
# file:  data/Os2Br6-9ebcce66be85_data.json found
# file:  data/Cl2Cr2O2-f0c029f3be24_data.json found
# file:  data/Co2Li2Sb2-5dd5e9f291b4_data.json found
# file:  data/I2Ni2O2-96fb249c879b_data.json found
# file:  data/NbSeTe-42c9fb2f24aa_data.json found
# file:  data/STaTe-9f5f42e019b2_data.json found
# file:  data/Ni2P2S6-de2432ed42aa_data.json found
# file:  data/Cu2F4-a4c46046b802_data.json found
# file:  data/Nb3Br8-61fe84ff83bc_data.json found
# file:  data/CrNbF6-6b60ae6d40fa_data.json found
# file:  data/Fe2Ga2S5-de048496d85d_data.json found
# file:  data/MnIn2Se4-47a23138b0d3_data.json found
# file:  data/Mn4Pb4O12-a4091fb78b1d_data.json found
# file:  data/Cl2O2V2-6b982cc914e3_data.json found
# file:  data/Cl2Fe2W2O8-e5531b8104fb_data.json found
# file:  data/Mn2Mo2Te2O12-00089eee5945_data.json found
# file:  data/Co2S2-0e8084b6b1d7_data.json found
# file:  data/Ni2O2-4f164abaf710_data.json found
# file:  data/Ni2Te2-725232091cb8_data.json found
# file:  data/AgCl2-5d923329973d_data.json found
# file:  data/CoF2-2f2f01730826_data.json found
# file:  data/CuBr2-22f552801137_data.json found
# file:  data/MnSe2-f3b9f9bddf25_data.json found
# file:  data/ScBr2-78039e746a9a_data.json found
# file:  data/Hf2Br6-a13511495a16_data.json found
# file:  data/Pd2Br6-ddb0a72d2720_data.json found
# file:  data/Ru2Cl6-7824d6bfa98a_data.json found
# file:  data/V2Br6-992373a7e1ea_data.json found
# file:  data/BrClV-878148656c6a_data.json found
# file:  data/Cl2Cr2S2-92b8a07f1c47_data.json found
# file:  data/Nb3I8-7a3db0aea4eb_data.json found
# file:  data/Cr2Nb2Se10-45494253aeeb_data.json found
# file:  data/Cu2Si2O6-af179bea7b63_data.json found
# file:  data/Fe2In2Se5-0ed2cc2c3a86_data.json found
# file:  data/OVCl2-1908527e4437_data.json found
# file:  data/Br2Mn2Sb2S4-5f544d911864_data.json found
# file:  data/F2N3Cr4-5a2f701da3f2_data.json found
# file:  data/Ni2O2-928c7a5db4e0_data.json found
# file:  data/AgCl2-cd8d815e268d_data.json found
# file:  data/CrCl2-bbfb87c2444a_data.json found
# file:  data/FeBr2-d7c6901921a7_data.json found
# file:  data/V2O4-81468f25ad40_data.json found
# file:  data/VTe2-0ad30b11e722_data.json found
# file:  data/Fe2Br6-867615d39c9d_data.json found
# file:  data/Hf2Cl6-55df638549b1_data.json found
# file:  data/Mo2I6-d182faf4b34d_data.json found
# file:  data/Pd2Cl6-0e06dc3e0222_data.json found
# file:  data/Ti2Br6-e43fad8616c0_data.json found
# file:  data/V2Br6-d9bbe81e24bb_data.json found
# file:  data/Br2Se2V2-39821785c8bb_data.json found
# file:  data/Cl2Cr2Se2-fb83a5a9c5f2_data.json found
# file:  data/Cl2Ni2O2-e707b28f9884_data.json found
# file:  data/Co2Na2Sb2-f33c020e4b65_data.json found
# file:  data/P2Ti2S6-1b2e64d113e5_data.json found
# file:  data/HfMnI6-502a8c200800_data.json found
# file:  data/NbF4-c980b1305b12_data.json found
# file:  data/Br2Fe2Sr3O5-607123e89187_data.json found
# file:  data/Br2Mn2Sb2Se4-273b68127629_data.json found
# file:  data/O2N3V4-c1f583efb536_data.json found
# file:  data/C3Zr4-70f55c32aafd_data.json found
# file:  data/Ni2O2-d8358a94a4a6_data.json found
# file:  data/Rh2S2-75d2f4af683a_data.json found
# file:  data/CoI2-614854de7677_data.json found
# file:  data/FeCl2-0af1baed7940_data.json found
# file:  data/MnI2-2b7cf85310ef_data.json found
# file:  data/MnTe2-66a6488e6059_data.json found
# file:  data/NbTe2-dc121d00820d_data.json found
# file:  data/PdCl2-e3731b3b3a79_data.json found
# file:  data/VO2-23bb81344202_data.json found
# file:  data/VTe2-45a0c1470922_data.json found
# file:  data/YCl2-097c5f54659a_data.json found
# file:  data/NiH2O2-4f81e6b4f5aa_data.json found
# file:  data/CH2Mn2O2-7938aedd38e3_data.json found
# file:  data/Fe2Br6-c559fabf0ecf_data.json found
# file:  data/Hf2Cl6-ce2074ea7bd9_data.json found
# file:  data/Os2Cl6-579e034365b4_data.json found
# file:  data/Ru2I6-c6558965584c_data.json found
# file:  data/Ti2Cl6-1aa6995ffbaa_data.json found
# file:  data/V2Cl6-8e5cf44cfd10_data.json found
# file:  data/BrClCr-d6f5234e76e0_data.json found
# file:  data/Cr2I2N2-2e0cbd48cd14_data.json found
# file:  data/STeV-05f16dc9de6b_data.json found
# file:  data/HfNiBr6-f5da1fb79dd2_data.json found
# file:  data/I2Y2-fabecc900154_data.json found
# file:  data/CrGa2Se4-08ad45ca8dd8_data.json found
# file:  data/Ga2Mn2S5-297a09935d97_data.json found
# file:  data/Mo2P2O10-fbd23d14819c_data.json found
# file:  data/NiV2Se4-6e08d64a6ddb_data.json found
# file:  data/Ag2V2P4S12-c1c84e694d17_data.json found
# file:  data/CoI2-b8ec8fbbcdc2_data.json found
# file:  data/FeCl2-a0004cbce0c5_data.json found
# file:  data/MnI2-49cdfdc22d83_data.json found
# file:  data/MnTe2-9a4fcdbcdd7a_data.json found
# file:  data/ScCl2-945f3bbaeedc_data.json found
# file:  data/ScSe2-b94c70080d61_data.json found
# file:  data/Fe2Cl6-694f11fd831a_data.json found
# file:  data/Hf2I6-03ec8f3f6481_data.json found
# file:  data/Pd2I6-152fee6d123c_data.json found
# file:  data/Ti2Cl6-a84bffeebbfa_data.json found
# file:  data/V2Cl6-bcfbab457bdd_data.json found
# file:  data/BrITi-c9d532173771_data.json found
# file:  data/Br2Mn2O2-536879d9eda9_data.json found
# file:  data/Cr2I2S2-a68f6e0481d3_data.json found
# file:  data/STeV-18374204965d_data.json found
# file:  data/H2Mn2O4-445db9a5d2cc_data.json found
# file:  data/HfNiCl6-1cbc55708ee3_data.json found
# file:  data/Nb3Cl8-51c6e4d2bd8d_data.json found
# file:  data/CrHO2-9c68093160c9_data.json found
# file:  data/NiGa2S4-e701ba2c76a0_data.json found
# file:  data/Mo2V2O10-0d9682591901_data.json found
# file:  data/NiCl2O8-87732aada027_data.json found
# file:  data/H2V2O5-df22927ea6d2_data.json found
# file:  data/Cl2Mn2Sb2S4-313196b2435e_data.json found
# file:  data/C2F2Y3-3a7aee4bc19d_data.json found
# file:  data/CuCl2-5fdd50d69b1f_data.json found
# file:  data/MnI2-c37f0a810838_data.json found
# file:  data/NiBr2-7937431cc8b7_data.json found
# file:  data/VBr2-606bfb261671_data.json found
# file:  data/VO2-d6e75c5ce82e_data.json found
# file:  data/Fe2Cl6-a7111f341a6a_data.json found
# file:  data/Hf2I6-271d56d42715_data.json found
# file:  data/Ti2I6-0e99355f14de_data.json found
# file:  data/V2I6-c0ce836c2f33_data.json found
# file:  data/Br2Fe2O2-71e19b5b951e_data.json found
# file:  data/BrIV-2da05db34435_data.json found
# file:  data/Br2Mn2Se2-fb1a2ad27d8a_data.json found
# file:  data/Cl4Se4Ti4-716f6cdbc2ad_data.json found
# file:  data/Cr2I2Se2-b4069f8b7f1c_data.json found
# file:  data/I2Se2V2-4644bda5f549_data.json found
# file:  data/H2Mn2S4-232e53d2739f_data.json found
# file:  data/CoHfBr6-b5dea6f7a711_data.json found
# file:  data/Cl2Y2-ae501357cefa_data.json found
# file:  data/Cr2Cu2O8-5375ba91153b_data.json found
# file:  data/KTiS2-c313157cab84_data.json found
# file:  data/CuHgTlBa2O5-3d7e75ba0021_data.json found
# file:  data/N3Mn4-0bb15dc7977c_data.json found
# file:  data/Cl2Sc2-a140231f9c03_data.json found
# file:  data/Cr2S2-885c9dcb98ad_data.json found
# file:  data/Fe2Se2-13ce8be7f1b2_data.json found
# file:  data/Ni2S2-45c8c6156f9b_data.json found
# file:  data/Se2V2-9556122e471e_data.json found
# file:  data/FeSe2-77c154839c24_data.json found
# file:  data/NiBr2-7b8108883def_data.json found
# file:  data/Fe2I6-615bc9238fbb_data.json found
# file:  data/Ni2Br6-8967959b58fc_data.json found
# file:  data/V2I6-fdc45f6a05cc_data.json found
# file:  data/ClITi-e63dbdea0d67_data.json found
# file:  data/Cl2Mn2N2-2e64187886f8_data.json found
# file:  data/Cl2Se2V2-b9824981c343_data.json found
# file:  data/CoHfF6-a1afa529df1b_data.json found
# file:  data/MnZrBr6-e6c3b44451c3_data.json found
# file:  data/Cd2Mn3O8-4e6825d4e3c8_data.json found
# file:  data/Cr2Ge2Te6-494eb20d87cf_data.json found
# file:  data/C2K2O6-720337d1b8c3_data.json found
# file:  data/I2Mn2Sb2Se4-501fd679dc2a_data.json found
# file:  data/C2Ca2F2O6-b46e73deeb64_data.json found
# file:  data/N2O2V3-358facb64a22_data.json found
# file:  data/CrI2-53a7a202e7c7_data.json found
# file:  data/MnO2-5cbde8fd417d_data.json found
# file:  data/V2Cl4-263a3693fb4f_data.json found
# file:  data/Ag2Br6-8e63ef562431_data.json found
# file:  data/Cr2Br6-e406fd4547de_data.json found
# file:  data/Fe2I6-c3c3634f1840_data.json found
# file:  data/Ni2Br6-981a39e4f968_data.json found
# file:  data/Pt2Br6-52ad72865776_data.json found
# file:  data/Cl2Fe2O2-60d6f215d057_data.json found
# file:  data/ClIV-9f3e8b6323b9_data.json found
# file:  data/Cl2Mn2O2-37cd5cb7c82e_data.json found
# file:  data/Fe2I2O2-e70846944452_data.json found
# file:  data/I2Mn2Se2-9fd5b951f464_data.json found
# file:  data/Fe2O4-3716e1d08772_data.json found
# file:  data/Cr2Si2Te6-64781dd6f055_data.json found
# file:  data/Cu4Te4O12-36ff2688b7a7_data.json found
# file:  data/H2O2N3Cr4-900cb08d8065_data.json found
# file:  data/CoO2-3efceb46b900_data.json found
# file:  data/CrI2-e0523db3dcd4_data.json found
# file:  data/FeI2-51934c0239e8_data.json found
# file:  data/FeSe2-bc711a51d5e7_data.json found
# file:  data/NiCl2-3ad667c285e2_data.json found
# file:  data/VS2-7bf3ed17a3da_data.json found
# file:  data/Cr2Cl6-9f9e75488d50_data.json found
# file:  data/Pt2Cl6-20b975a3a1e8_data.json found
# file:  data/Br2N2V2-186b2da4920f_data.json found
# file:  data/Cl2Mn2Se2-6bdadd86e6c4_data.json found
# file:  data/SSeV-0f3ba3ea815f_data.json found

# %%
import json

scell_dim= 2;
uMnSe2= 'MnSe2-f3b9f9bddf25'; uMnBi2Te4 = 'MnBi2Te4-a8bb2517b2b7';
uCrI3 = 'Cr2I6-462e253dd5f0';
uBrCrS = 'Br2Cr2S2-806bd2cbdf65';
uFeGeTe = 'GeTe2Fe3-38cc35ba8ee5';
uVSTe= 'STeV-05f16dc9de6b';
uNi2P2S6 = 'Ni2P2S6-de2432ed42aa';
uCr3Te4= 'Cr3Te4-3d365d19d9c9'
uFe2O4= "Fe2O4-3716e1d08772"
uV2Br6 = 'V2Br6-992373a7e1ea';
uCrI2 = 'CoBr2-807b6a88f950';
uFeTe2_p4 = 'Fe2Te2-b49eca087529';
uCrGeTe = 'Cr2Ge2Te6-494eb20d87cf';
uLi2Mn2P2= 'Li2Mn2P2-32e0950b0bbb';
uid = uCrI2

print(raw_df[raw_df.uid==uid])

with open('./data/'+uid+'_data.json', 'r') as file:
    for line in file:
        print("load: ",file)
        full_system_data = json.loads(line);

atoms = full_system_data['results-asr.bader.json']['kwargs']['data']['sym_a'];
a1,a2,a3     = dbelem2array( full_system_data['structure.json']['1']['cell']['array'] );
positions= dbelem2array(full_system_data['structure.json']['1']['positions'] );
positions= list(zip(atoms,positions));
sc_pos = [ [a,np.round(p + n1*a1 + n2*a2,4)] for a,p in positions for n1 in np.arange(scell_dim) for n2 in np.arange(scell_dim) ]
print("HAS INVERSION:",full_system_data['results-asr.structureinfo.json']['kwargs']['data']['has_inversion_symmetry'])
# Out:
#    formula  spgnum spacegroup     dE_zx     dE_zy       lam    magmom  \
# 80   CoBr2     115      P-4m2 -0.068329 -0.068306  0.001689  2.999999
#
#    magstate   doi                 uid
# 80       FM  None  CoBr2-807b6a88f950
# load:  <_io.TextIOWrapper name='./data/CoBr2-807b6a88f950_data.json' mode='r' encoding='UTF-8'>
# HAS INVERSION: False

# %%
from copy import copy

toabs = np.array([a1,a2,a3]).T;
tofrac= np.linalg.inv(toabs);
sites = copy(positions);

# %%
eye = np.array( [[1,0,0],[0,1,0],[0,0,1]]);
I = np.array( [[-1,0,0],[0,-1,0],[0,0,-1]]);
my= np.array( [[ 1,0,0],[0,-1,0],[0,0, 1]]);
mx= np.array( [[-1,0,0],[0, 1,0],[0,0, 1]]);
mz= np.array( [[ 1,0,0],[0, 1,0],[0,0,-1]]);

def Cz(n):
    tn = 2*np.pi/n;
    return np.array( [ [np.cos(tn),-np.sin(tn),0],[np.sin(tn),np.cos(tn),0],[0,0,1]]);
def Cy(n):
    tn = 2*np.pi/n;
    return np.array( [ [np.cos(tn),0,np.sin(tn)],[0,1,0],[-np.sin(tn),0,np.cos(tn)]]);
def Cx(n):
    tn = 2*np.pi/n;
    return np.array( [ [1,0,0],[0,np.cos(tn),-np.sin(tn)],[0,np.sin(tn),np.cos(tn)]]);

inv      = ("inv", I  );
mzmy     = ("mzmy", mz.dot(my)  );
mzC2y2   = ("mzC2y", mz.dot(Cy(2))  );
mxC2x    = ("mxC2x", mx.dot(Cx(2))  );
identity = ("identity", np.array( [[ 1,0,0],[0, 1,0],[0,0, 1]]) );

sym_list = (identity,inv,mzCy2,mzmy,mxC2x);

def is_int(x):
    iterator = ();
    if isinstance(x, (int,float, complex)):
        iterator= (x,);
    else:
        try:
            iterator = iter(x);
        except:
            print("not list or primitive return false");
            return false;
    return np.all([ np.abs(x-np.round(x,0))<1e-2 for x in iterator]);

def isSymmetry( R ,sites ):
    return np.all([ np.any([(a0==a1 and  is_int(tofrac.dot(R.dot(r1)-r0)) ) for a1,r1 in sites]) for a0,r0 in sites ]);

for sym in sym_list:
    label, R = sym;
    if isSymmetry( R,sites ):
        print(label, "is a symmetry")
    else:
        print(label, "is not a symmetry")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-94c0658d2f96> in <module>
#      21 identity = ("identity", np.array( [[ 1,0,0],[0, 1,0],[0,0, 1]]) );
#      22
# ---> 23 sym_list = (identity,inv,mzCy2,mzmy,mxC2x);
#      24
#      25 def is_int(x):
#
# NameError: name 'mzCy2' is not defined

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = spacegroups[:10];
sizes = 100*counts[:10]/ np.sum(counts)
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, startangle=90,  wedgeprops=dict(width=0.5, edgecolor='k'),)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

fig= plt.gcf();
fig.savefig("pieplot.pdf")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]

data = [225, 90, 50, 60, 100, 5]

wedges, texts = ax.pie(data,startangle=-40)

#bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
#kw = dict(arrowprops=dict(arrowstyle="-"),
#          bbox=bbox_props, zorder=0, va="center")

#for i, p in enumerate(wedges):
 #   ang = (p.theta2 - p.theta1)/2. + p.theta1
 #   y = np.sin(np.deg2rad(ang))
   # x = np.cos(np.deg2rad(ang))
 ##   horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
 #   connectionstyle = "angle,angleA=0,angleB={}".format(ang)
  #  kw["arrowprops"].update({"connectionstyle": connectionstyle})
#    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
  #              horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
#Remove cases with no effective masses
#raw_df = raw_df[raw_df.emass_cb_dir1.notna() & raw_df.emass_cb_dir2.notna() & raw_df.emass_vb_dir1.notna() & raw_df.emass_vb_dir2.notna()]
#Remove cases with no gaps
#df = raw_df[raw_df.gap_dir.notna() | raw_df.gap_dir_hse.notna() | raw_df.gap_dir_gw.notna() ]
df["cb_ani"] = raw_df.emass_cb_dir1/raw_df.emass_cb_dir2;
df["vb_ani"] = raw_df.emass_vb_dir1/raw_df.emass_vb_dir2;

min_ani = 0.1
df = df[ df.cb_ani.apply( lambda x: np.abs(x-1.0)>min_ani ) | df.vb_ani.apply( lambda x: np.abs(x-1.0)>min_ani )]

min_gap = 100e-3;
max_gap = 400e-3;
#df = df[ ( min_gap<df.gap_dir) & (df.gap_dir<max_gap) | ( min_gap<df.gap_dir_hse) & (df.gap_dir_hse<max_gap)| ( min_gap<df.gap_dir_gw) & (df.gap_dir_gw<max_gap)]
df = df[ ( min_gap<df.gap_dir_hse) & (df.gap_dir_hse<max_gap)]

print("there are ", len(df), "left")

df

# %%
import wget
for uid in df.uid:
    daturl = 'https://cmrdb.fysik.dtu.dk/c2db/row/'+uid+'/all_data';
    print(wget.download(daturl, out='./data/'))

# %% [markdown]
# # Plot the band structure to demonstrate the bandgap

# %%
import json
import matplotlib.pyplot as plt

def plot_band_structure(uid):
    full_bandstructure_data = [];    
    with open('./data/'+uid+'_data.json', 'r') as file:
        for line in file:
            full_bandstructure_data = json.loads(line);

    bandstructure = full_bandstructure_data.get('results-asr.bandstructure.json').get('kwargs').get('data').get('bs_soc');
    EF = bandstructure.get('efermi')

    shape, dtype, data=  bandstructure.get('energies')['__ndarray__'];
    bands = np.array(data,dtype=dtype).reshape(shape)-EF;

    path = bandstructure.get('path');
    shape, dtype, data=  path.get('kpts')['__ndarray__'];
    kpoints = np.array(data,dtype=dtype).reshape(shape);

    shape, dtype, data= path.get('cell').get('array').get('__ndarray__');
    lat_vec = np.array(data,dtype=dtype).reshape(shape).T; lat_vec[2,2]=1
    rec_vec = np.linalg.inv(lat_vec).T

    ticks_labels, ticks_pos = [], [];
    for l in path.get('special_points').keys(): 
        shape, dtype, data = path.get('special_points').get(l).get('__ndarray__');
        tick_pos = np.array(data,dtype=dtype).reshape(shape);
        ticks_pos.append(tick_pos);
        ticks_labels.append(l);
    ticks_pos = [ np.argmin( np.linalg.norm(k-kpoints,axis=1)) for k in ticks_pos]

    X = np.cumsum(np.linalg.norm(np.diff(kpoints.dot(rec_vec),axis=0,prepend=0),axis=1));
    X = X/X.max();

    import matplotlib.pyplot as plt
    for Y in bands:
        plt.plot(X,Y);
    plt.ylim(-1,1);

    plt.xticks( X[ticks_pos]);
    plt.gca().set_xticklabels(ticks_labels);

# %%
for f,sg,uid in zip(df.formula,df.spacegroup, df.uid):
    print(f,sg, uid)
    plot_band_structure(uid);
    plt.show();

# %%
ticks_labels

# %%
lat_vec

# %%
import matplotlib.pyplot as plt
for Y in bands:
    plt.plot(X,Y);
plt.ylim(-1,1)

# %%
 bandstructure_data.get('results-asr.bandstructure.json').get('kwargs')
