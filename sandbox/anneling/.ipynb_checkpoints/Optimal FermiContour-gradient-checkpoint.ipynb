# %%
import numpy as np
from numpy.linalg import inv, det


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

from anneling_grad import GradientAnnealing

import random
random.seed(99)

# %%
def xyz_gen(gen, function):
    
    x=[x[0] for x in gen]
    y=[x[1] for x in gen]
    z=[function([x[i],y[i]]) for i in range(len(gen))]
    return x,y,z

# %%
N1 = 100
N2 = 100
Ef = 2
EfI=  Ef*np.array([[1,0],[0,1]])
piI = 2*np.pi* np.array([[1,0],[0,1]])

A = np.array([ [1/2, np.sqrt(3)/2],
               [1/2, -np.sqrt(3)/2]]).T
invA= inv(A)
B = 2*np.pi*invA.T

def H_mat(n1,n2):
    
    k = (n1/N1)*B[:,0]+(n2/N2)*B[:,1]
    
    ka1=np.dot(A[:,0],k) # ka1,k2 = np.dot(A,k)
    ka2=np.dot(A[:,1],k)
    
    f = np.exp(1j*ka1)+ np.exp(1j*ka2)+1 
    
    f_conj= np.conj(f)
    
    H = np.array([[0, f],[f_conj,0]])
    
    return H

def det_sq(n1,n2):
    
    det_H= det( H_mat(n1,n2)-EfI )

    return np.real(det_H)*np.real(det_H)

def bands_F(n1,n2):
    
    bands= np.linalg.eigvals( H_mat(n1,n2) )

    return np.real(bands)

# %%
X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
bands= np.transpose([[ bands_F(x1,x2) for x2 in X2] for x1 in X1], axes=[2,1,0])
print(bands.shape)  

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

for band in bands:

    surf = ax.plot_surface(X1, X2, band, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
    

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# (2, 100, 100)

# %%
def fit_function(x):

    return det_sq(x[0],x[1])

X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
Z= np.array([fit_function([x1,x2]) for x2 in X2 for x1 in X1])
print("zsort:",np.sort(Z)[:5]) 

Z= np.array([[fit_function([x1,x2]) for x2 in X2] for x1 in X1])

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X1, X2, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# zsort: [2.74623303e-05 2.74623303e-05 2.74623303e-05 2.74623303e-05
#  2.74623303e-05]

# %%
# Experiment settings

#Hyperparameters of the model
model_par = {
    
    'initialTemp': 1, 
    'finalTemp': 0.0003,

    'beta': 10,
    'bounds': [[1,N1],[1,N2]],

    'nr_neighbours': 1,
    'gaussian_sd':5,
    
    'gradient_influence':0.45,
    'delta_p': 0.2,
    'g_step_size':7,
    'step_size': 4,
    
    
    
    'known_min': 8.76763323079435e-05
    
}

#
input_size = 2 # since our function has one variable this is a trivial scenario.
start_point = [20, 30]

# Experiment
experiment = GradientAnnealing(fit_function,start_point, model_par)

# %%
epochs= 5
history_book = experiment.evolve( epochs, prints_p=5)
# Out:
# temp:1|epoch:0|change:0.5079772240320783|value:0.8899432352821851
# temp:0.09090909090909091|epoch:0|change:0.21869021544819606|value:0.25942927348279826
# temp:0.047619047619047616|epoch:0|change:0.23750861543542082|value:0.08511724372650684
# temp:0.03225806451612903|epoch:0|change:0.3440221275647978|value:0.08511724372650684
# temp:0.024390243902439025|epoch:0|change:0.4880489113575431|value:0.0783779584249958
# temp:0.0196078431372549|epoch:0|change:3.1809521392888533|value:0.019948182471679697
# temp:0.01639344262295082|epoch:0|change:0.6098506869123528|value:0.0005579446682840464
# temp:0.014084507042253523|epoch:0|change:2.923762578515069|value:0.00227702980649009
# temp:0.01234567901234568|epoch:0|change:1.2384084645679658|value:0.00227702980649009
# temp:0.010989010989010988|epoch:0|change:0.6030332210499807|value:0.00227702980649009

# %%
final_solution = experiment.actual_solution
final_value = fit_function(experiment.actual_solution)
print("final_solution:",final_solution)
print("final_value:",final_value)
# Out:
# final_solution: [28, 30]
# final_value: 7.33971778661323e-05

# %%
solutions = []
solution_values=[]
for s1 in range(-100,100 ,30):
    for s2 in range(-80,80, 30):
        start_point =[s1,s2]
        experiment = GradientAnnealing(fit_function,start_point, model_par)
        experiment.evolve( epochs, prints_p=999, tr_print=False)
        solutions.append(experiment.actual_solution)
        solution_values.append(experiment.actual_value)
        print("start points:{} |solution:{} |value:{}".format(start_point,experiment.actual_solution,experiment.actual_value))
# Out:
# start points:[-100, -80] |solution:[-100, -80] |value:5.000000000000004
# start points:[-100, -50] |solution:[-100, -50] |value:8.999999999999998
# start points:[-100, -20] |solution:[-100, -20] |value:5.000000000000008
# start points:[-100, 10] |solution:[33, 12] |value:6.708132582787499e-05
# start points:[-100, 40] |solution:[21, 33] |value:6.708132582789974e-05
# start points:[-100, 70] |solution:[2, 72] |value:7.339717786606644e-05
# start points:[-70, -80] |solution:[-70, -80] |value:0.3819660112501055
# start points:[-70, -50] |solution:[-70, -50] |value:9.000000000000004
# start points:[-70, -20] |solution:[-70, -20] |value:8.999999999999998
# start points:[-70, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-70, 40] |solution:[2, 30] |value:7.339717786613178e-05
# start points:[-70, 70] |solution:[12, 79] |value:6.708132582787883e-05
# start points:[-40, -80] |solution:[-40, -80] |value:13.090169943749475
# start points:[-40, -50] |solution:[-40, -50] |value:8.999999999999998
# start points:[-40, -20] |solution:[-40, -20] |value:1.9098300562505237
# start points:[-40, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-40, 40] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-40, 70] |solution:[29, 100] |value:2.7462330252995567e-05
# start points:[-10, -80] |solution:[-10, -80] |value:0.38196601125010565
# start points:[-10, -50] |solution:[-10, -50] |value:8.999999999999998
# start points:[-10, -20] |solution:[-10, -20] |value:8.145898033750314
# start points:[-10, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-10, 40] |solution:[2, 30] |value:7.339717786613178e-05
# start points:[-10, 70] |solution:[21, 88] |value:6.708132582787883e-05
# start points:[20, -80] |solution:[28, 30] |value:7.33971778661323e-05
# start points:[20, -50] |solution:[33, 12] |value:6.708132582787499e-05
# start points:[20, -20] |solution:[29, 29] |value:2.74623302530024e-05
# start points:[20, 10] |solution:[30, 2] |value:7.339717786613178e-05
# start points:[20, 40] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[20, 70] |solution:[12, 79] |value:6.708132582787883e-05
# start points:[50, -80] |solution:[33, 21] |value:6.708132582789974e-05
# start points:[50, -50] |solution:[30, 2] |value:7.339717786613178e-05
# start points:[50, -20] |solution:[72, 2] |value:7.339717786606644e-05
# start points:[50, 10] |solution:[79, 12] |value:6.708132582787883e-05
# start points:[50, 40] |solution:[67, 88] |value:6.708132582787048e-05
# start points:[50, 70] |solution:[72, 70] |value:7.339717786617104e-05
# start points:[80, -80] |solution:[79, 12] |value:6.708132582787883e-05
# start points:[80, -50] |solution:[72, 2] |value:7.339717786606644e-05
# start points:[80, -20] |solution:[88, 21] |value:6.708132582787883e-05
# start points:[80, 10] |solution:[72, 2] |value:7.339717786606644e-05
# start points:[80, 40] |solution:[71, 71] |value:2.7462330252969075e-05
# start points:[80, 70] |solution:[71, 100] |value:2.7462330252979903e-05

# %%
solutions
# Out:
# [[-100, -80],
#  [-100, -50],
#  [-100, -20],
#  [33, 12],
#  [21, 33],
#  [2, 72],
#  [-70, -80],
#  [-70, -50],
#  [-70, -20],
#  [12, 33],
#  [2, 30],
#  [12, 79],
#  [-40, -80],
#  [-40, -50],
#  [-40, -20],
#  [12, 33],
#  [12, 33],
#  [29, 100],
#  [-10, -80],
#  [-10, -50],
#  [-10, -20],
#  [12, 33],
#  [2, 30],
#  [21, 88],
#  [28, 30],
#  [33, 12],
#  [29, 29],
#  [30, 2],
#  [12, 33],
#  [12, 79],
#  [33, 21],
#  [30, 2],
#  [72, 2],
#  [79, 12],
#  [67, 88],
#  [72, 70],
#  [79, 12],
#  [72, 2],
#  [88, 21],
#  [72, 2],
#  [71, 71],
#  [71, 100]]

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_67452/4267174279.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# Clen the results
tollerance = model_par['known_min']
clean_solutions=[]
for i in range(len(solutions)):
    if solution_values[i] <= tollerance:
        clean_solutions.append(solutions[i])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(clean_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_67452/3868486351.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)
