# %%
import numpy as np
from numpy.linalg import inv, det


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

from anneling_one import Annealing1
from hook import discrete_hook

import random
random.seed(99)

# %%
def xyz_gen(gen, function):
    
    x=[x[0] for x in gen]
    y=[x[1] for x in gen]
    z=[function([x[i],y[i]]) for i in range(len(gen))]
    return x,y,z

# %%
N1 = 100
N2 = 100
Ef = 2
EfI=  Ef*np.array([[1,0],[0,1]])
piI = 2*np.pi* np.array([[1,0],[0,1]])

A = np.array([ [1/2, np.sqrt(3)/2],
               [1/2, -np.sqrt(3)/2]]).T
invA= inv(A)
B = 2*np.pi*invA.T

def H_mat(n1,n2):
    
    k = (n1/N1)*B[:,0]+(n2/N2)*B[:,1]
    
    ka1=np.dot(A[:,0],k) # ka1,k2 = np.dot(A,k)
    ka2=np.dot(A[:,1],k)
    
    f = np.exp(1j*ka1)+ np.exp(1j*ka2)+1 
    
    f_conj= np.conj(f)
    
    H = np.array([[0, f],[f_conj,0]])
    
    return H

def det_sq(n1,n2):
    
    det_H= det( H_mat(n1,n2)-EfI )

    return np.real(det_H)*np.real(det_H)

def bands_F(n1,n2):
    
    bands= np.linalg.eigvals( H_mat(n1,n2) )

    return np.real(bands)

# %%
X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
bands= np.transpose([[ bands_F(x1,x2) for x2 in X2] for x1 in X1], axes=[2,1,0])
print(bands.shape)  

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

for band in bands:

    surf = ax.plot_surface(X1, X2, band, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
    

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# (2, 100, 100)

# %%
def fit_function(x):

    return det_sq(x[0],x[1])

X1 =  np.arange(0, N1, 1)
X2 =  np.arange(0, N2, 1)

              
Z= np.array([fit_function([x1,x2]) for x2 in X2 for x1 in X1])
print("zsort:",np.sort(Z)[:5]) 

Z= np.array([[fit_function([x1,x2]) for x2 in X2] for x1 in X1])

X1, X2 = np.meshgrid(X1, X2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X1, X2, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# zsort: [2.74623303e-05 2.74623303e-05 2.74623303e-05 2.74623303e-05
#  2.74623303e-05]

# %%
# Experiment settings

#Hyperparameters of the model
model_par = {
    
    'initialTemp': 1, 
    'finalTemp': 0.0003,

    'beta': 10,
    'bounds': [[1,N1],[1,N2]],

    'nr_neighbours': 1,
    'step_size': 4,
    'gaussian_sd':5,
    
    'known_min': 8.76763323079435e-05
    
}

#
input_size = 2 # since our function has one variable this is a trivial scenario.
start_point = [20, 30]

# Experiment
experiment = Annealing1(fit_function,start_point, model_par)

# %%
epochs= 5
history_book = experiment.evolve( epochs, prints_p=5)
# Out:
# temp:1|epoch:0|change:0.5679830199685423|value:0.9499490312186489
# temp:0.09090909090909091|epoch:0|change:2.8126814514772214|value:0.5607582332496694
# temp:0.047619047619047616|epoch:0|change:1.3779933416301768|value:0.002474987899512062
# temp:0.03225806451612903|epoch:0|change:0.0063656023113303935|value:0.015353949143640936
# temp:0.024390243902439025|epoch:0|change:0.2254551019000325|value:0.009191832615660088
# temp:0.0196078431372549|epoch:0|change:-0.0005909910091995325|value:0.02144386323313037
# temp:0.01639344262295082|epoch:0|change:0.7855651919647619|value:0.009191832615660088
# temp:0.014084507042253523|epoch:0|change:0.22022345692181544|value:0.015353949143640936

# %%
final_solution = experiment.actual_solution
final_value = fit_function(experiment.actual_solution)
print("final_solution:",final_solution)
print("final_value:",final_value)
# Out:
# final_solution: [12, 33]
# final_value: 6.708132582787499e-05

# %%
solutions = []
solution_values=[]
for s1 in range(-100,100 ,30):
    for s2 in range(-80,80, 30):
        start_point =[s1,s2]
        experiment = Annealing1(fit_function,start_point, model_par)
        experiment.evolve( epochs, prints_p=999, tr_print=False)
        solutions.append(experiment.actual_solution)
        solution_values.append(experiment.actual_value)
        print("start points:{} |solution:{} |value:{}".format(start_point,experiment.actual_solution,experiment.actual_value))
# Out:
# start points:[-100, -80] |solution:[-100, -80] |value:5.000000000000004
# start points:[-100, -50] |solution:[-100, -50] |value:8.999999999999998
# start points:[-100, -20] |solution:[-100, -20] |value:5.000000000000008
# start points:[-100, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-100, 40] |solution:[28, 30] |value:7.33971778661323e-05
# start points:[-100, 70] |solution:[12, 79] |value:6.708132582787883e-05
# start points:[-70, -80] |solution:[-70, -80] |value:0.3819660112501055
# start points:[-70, -50] |solution:[-70, -50] |value:9.000000000000004
# start points:[-70, -20] |solution:[-70, -20] |value:8.999999999999998
# start points:[-70, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[-70, 40] |solution:[29, 29] |value:2.74623302530024e-05
# start points:[-70, 70] |solution:[21, 88] |value:6.708132582787883e-05
# start points:[-40, -80] |solution:[-40, -80] |value:13.090169943749475
# start points:[-40, -50] |solution:[-40, -50] |value:8.999999999999998
# start points:[-40, -20] |solution:[-40, -20] |value:1.9098300562505237
# start points:[-40, 10] |solution:[33, 21] |value:6.708132582789974e-05
# start points:[-40, 40] |solution:[21, 33] |value:6.708132582789974e-05
# start points:[-40, 70] |solution:[12, 79] |value:6.708132582787883e-05
# start points:[-10, -80] |solution:[-10, -80] |value:0.38196601125010565
# start points:[-10, -50] |solution:[-10, -50] |value:8.999999999999998
# start points:[-10, -20] |solution:[-10, -20] |value:8.145898033750314
# start points:[-10, 10] |solution:[2, 30] |value:7.339717786613178e-05
# start points:[-10, 40] |solution:[30, 28] |value:7.33971778661323e-05
# start points:[-10, 70] |solution:[28, 98] |value:7.339717786606475e-05
# start points:[20, -80] |solution:[30, 2] |value:7.339717786613178e-05
# start points:[20, -50] |solution:[29, 29] |value:2.74623302530024e-05
# start points:[20, -20] |solution:[33, 12] |value:6.708132582787499e-05
# start points:[20, 10] |solution:[12, 33] |value:6.708132582787499e-05
# start points:[20, 40] |solution:[21, 33] |value:6.708132582789974e-05
# start points:[20, 70] |solution:[2, 72] |value:7.339717786606644e-05
# start points:[50, -80] |solution:[79, 12] |value:6.708132582787883e-05
# start points:[50, -50] |solution:[100, 29] |value:2.7462330252995567e-05
# start points:[50, -20] |solution:[30, 2] |value:7.339717786613178e-05
# start points:[50, 10] |solution:[29, 29] |value:2.74623302530024e-05
# start points:[50, 40] |solution:[28, 30] |value:7.33971778661323e-05
# start points:[50, 70] |solution:[79, 67] |value:6.708132582784447e-05
# start points:[80, -80] |solution:[79, 12] |value:6.708132582787883e-05
# start points:[80, -50] |solution:[88, 21] |value:6.708132582787883e-05
# start points:[80, -20] |solution:[88, 21] |value:6.708132582787883e-05
# start points:[80, 10] |solution:[72, 2] |value:7.339717786606644e-05
# start points:[80, 40] |solution:[71, 71] |value:2.7462330252969075e-05
# start points:[80, 70] |solution:[98, 70] |value:7.339717786616554e-05

# %%
solutions
# Out:
# [[-100, -80],
#  [-100, -50],
#  [-100, -20],
#  [12, 33],
#  [28, 30],
#  [12, 79],
#  [-70, -80],
#  [-70, -50],
#  [-70, -20],
#  [12, 33],
#  [29, 29],
#  [21, 88],
#  [-40, -80],
#  [-40, -50],
#  [-40, -20],
#  [33, 21],
#  [21, 33],
#  [12, 79],
#  [-10, -80],
#  [-10, -50],
#  [-10, -20],
#  [2, 30],
#  [30, 28],
#  [28, 98],
#  [30, 2],
#  [29, 29],
#  [33, 12],
#  [12, 33],
#  [21, 33],
#  [2, 72],
#  [79, 12],
#  [100, 29],
#  [30, 2],
#  [29, 29],
#  [28, 30],
#  [79, 67],
#  [79, 12],
#  [88, 21],
#  [88, 21],
#  [72, 2],
#  [71, 71],
#  [98, 70]]

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_68560/4267174279.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# Clen the results
tollerance = model_par['known_min']
clean_solutions=[]
for i in range(len(solutions)):
    if solution_values[i] <= tollerance:
        clean_solutions.append(solutions[i])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(clean_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_68560/3868486351.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# now we need to be sure that we extract a complet contour

explored = []

total_solutions = []
total_values = []
for solution in clean_solutions:
    if solution not in explored:
        explored.append(solution)
        
        extend_solutions, extended_values = discrete_hook(fit_function,solution,boundary=[[-100,100],[-100,100]],tolerance =0.05)
        print("extended_solutions:",extend_solutions)
        for i in range(len(extend_solutions)):
            s=extend_solutions[i]
            v= extended_values[i]
            total_solutions.append(s)
            total_values.append(v)
# Out:
# good_neighbour: [13, 33]
# good_neighbour: [11, 33]
# good_neighbour: [11, 32]
# good_neighbour: [13, 34]
# good_neighbour: [14, 33]
# len to explore 6
# good_neighbour: [12, 33]
# good_neighbour: [14, 34]
# good_neighbour: [15, 33]
# len to explore 8
# good_neighbour: [10, 33]
# good_neighbour: [10, 32]
# len to explore 9
# len to explore 8
# good_neighbour: [15, 34]
# len to explore 8
# good_neighbour: [16, 33]
# len to explore 8
# len to explore 7
# good_neighbour: [16, 34]
# len to explore 7
# good_neighbour: [17, 33]
# len to explore 7
# good_neighbour: [9, 33]
# good_neighbour: [9, 32]
# len to explore 8
# len to explore 7
# good_neighbour: [17, 34]
# len to explore 7
# good_neighbour: [18, 33]
# len to explore 7
# good_neighbour: [18, 34]
# len to explore 7
# good_neighbour: [19, 33]
# len to explore 7
# good_neighbour: [8, 33]
# good_neighbour: [8, 32]
# good_neighbour: [7, 31]
# len to explore 9
# len to explore 8
# good_neighbour: [19, 34]
# len to explore 8
# good_neighbour: [20, 33]
# len to explore 8
# good_neighbour: [20, 34]
# len to explore 8
# good_neighbour: [21, 33]
# len to explore 8
# good_neighbour: [7, 32]
# good_neighbour: [6, 31]
# len to explore 9
# len to explore 8
# good_neighbour: [6, 32]
# len to explore 8
# good_neighbour: [21, 34]
# len to explore 8
# good_neighbour: [21, 32]
# good_neighbour: [22, 33]
# len to explore 9
# len to explore 8
# good_neighbour: [22, 32]
# good_neighbour: [23, 33]
# len to explore 9
# len to explore 8
# good_neighbour: [5, 31]
# good_neighbour: [5, 32]
# len to explore 9
# good_neighbour: [4, 30]
# len to explore 9
# len to explore 8
# good_neighbour: [23, 32]
# len to explore 8
# good_neighbour: [24, 33]
# len to explore 8
# good_neighbour: [24, 32]
# len to explore 8
# good_neighbour: [25, 33]
# len to explore 8
# good_neighbour: [4, 31]
# len to explore 8
# good_neighbour: [3, 30]
# len to explore 8
# good_neighbour: [3, 31]
# len to explore 8
# good_neighbour: [24, 31]
# good_neighbour: [25, 32]
# len to explore 9
# len to explore 8
# good_neighbour: [25, 31]
# good_neighbour: [26, 32]
# len to explore 9
# len to explore 8
# len to explore 7
# good_neighbour: [2, 30]
# len to explore 7
# good_neighbour: [1, 29]
# len to explore 7
# good_neighbour: [26, 31]
# len to explore 7
# good_neighbour: [27, 32]
# len to explore 7
# good_neighbour: [26, 30]
# good_neighbour: [27, 31]
# len to explore 8
# len to explore 7
# good_neighbour: [1, 30]
# len to explore 7
# good_neighbour: [0, 29]
# len to explore 7
# good_neighbour: [27, 30]
# good_neighbour: [28, 31]
# len to explore 8
# len to explore 7
# good_neighbour: [28, 30]
# len to explore 7
# len to explore 6
# good_neighbour: [-1, 28]
# len to explore 6
# good_neighbour: [-1, 29]
# len to explore 6
# good_neighbour: [28, 29]
# good_neighbour: [29, 30]
# len to explore 7
# len to explore 6
# good_neighbour: [29, 29]
# len to explore 6
# good_neighbour: [-2, 28]
# len to explore 6
# good_neighbour: [-3, 27]
# len to explore 6
# good_neighbour: [29, 28]
# good_neighbour: [30, 29]
# len to explore 7
# len to explore 6
# good_neighbour: [30, 28]
# len to explore 6
# good_neighbour: [-3, 28]
# good_neighbour: [-4, 26]
# len to explore 7
# good_neighbour: [-4, 27]
# len to explore 7
# good_neighbour: [30, 27]
# good_neighbour: [31, 28]
# len to explore 8
# len to explore 7
# good_neighbour: [31, 27]
# len to explore 7
# good_neighbour: [-5, 26]
# len to explore 7
# good_neighbour: [-5, 27]
# len to explore 7
# good_neighbour: [-6, 25]
# len to explore 7
# good_neighbour: [30, 26]
# good_neighbour: [31, 26]
# good_neighbour: [32, 27]
# len to explore 9
# len to explore 8
# good_neighbour: [32, 26]
# len to explore 8
# good_neighbour: [-6, 26]
# good_neighbour: [-7, 24]
# len to explore 9
# good_neighbour: [-7, 25]
# len to explore 9
# len to explore 8
# good_neighbour: [31, 25]
# len to explore 8
# good_neighbour: [32, 25]
# len to explore 8
# len to explore 7
# good_neighbour: [33, 25]
# len to explore 7
# good_neighbour: [-8, 24]
# len to explore 7
# good_neighbour: [-8, 25]
# len to explore 7
# good_neighbour: [-9, 23]
# len to explore 7
# good_neighbour: [31, 24]
# good_neighbour: [32, 24]
# len to explore 8
# good_neighbour: [33, 24]
# len to explore 8
# len to explore 7
# good_neighbour: [-9, 24]
# good_neighbour: [-10, 22]
# len to explore 8
# good_neighbour: [-10, 23]
# len to explore 8
# good_neighbour: [-11, 21]
# len to explore 8
# good_neighbour: [32, 23]
# len to explore 8
# good_neighbour: [33, 23]
# len to explore 8
# len to explore 7
# good_neighbour: [-11, 22]
# len to explore 7
# len to explore 6
# good_neighbour: [-12, 21]
# len to explore 6
# len to explore 5
# good_neighbour: [32, 22]
# good_neighbour: [33, 22]
# len to explore 6
# len to explore 5
# good_neighbour: [-13, 20]
# len to explore 5
# good_neighbour: [-13, 21]
# good_neighbour: [-14, 19]
# len to explore 6
# good_neighbour: [32, 21]
# good_neighbour: [33, 21]
# len to explore 7
# good_neighbour: [34, 21]
# len to explore 7
# good_neighbour: [-14, 20]
# good_neighbour: [-15, 18]
# len to explore 8
# good_neighbour: [-15, 19]
# len to explore 8
# good_neighbour: [-16, 17]
# len to explore 8
# good_neighbour: [33, 20]
# len to explore 8
# good_neighbour: [34, 20]
# len to explore 8
# len to explore 7
# good_neighbour: [-16, 18]
# len to explore 7
# good_neighbour: [-17, 16]
# len to explore 7
# good_neighbour: [-17, 17]
# len to explore 7
# good_neighbour: [-18, 15]
# len to explore 7
# good_neighbour: [33, 19]
# good_neighbour: [34, 19]
# len to explore 8
# len to explore 7
# good_neighbour: [-18, 16]
# len to explore 7
# good_neighbour: [-19, 14]
# len to explore 7
# good_neighbour: [-19, 15]
# len to explore 7
# good_neighbour: [-20, 13]
# len to explore 7
# good_neighbour: [33, 18]
# good_neighbour: [34, 18]
# len to explore 8
# len to explore 7
# good_neighbour: [-20, 14]
# len to explore 7
# good_neighbour: [-21, 12]
# len to explore 7
# good_neighbour: [-21, 13]
# len to explore 7
# good_neighbour: [-22, 11]
# len to explore 7
# good_neighbour: [33, 17]
# good_neighbour: [34, 17]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [-21, 11]
# good_neighbour: [-23, 10]
# len to explore 7
# len to explore 6
# good_neighbour: [-22, 10]
# good_neighbour: [-24, 9]
# len to explore 7
# good_neighbour: [33, 16]
# good_neighbour: [34, 16]
# len to explore 8
# len to explore 7
# good_neighbour: [-23, 9]
# len to explore 7
# good_neighbour: [-25, 8]
# len to explore 7
# good_neighbour: [-24, 8]
# len to explore 7
# len to explore 6
# good_neighbour: [33, 15]
# good_neighbour: [34, 15]
# len to explore 7
# len to explore 6
# good_neighbour: [-25, 7]
# len to explore 6
# good_neighbour: [-24, 7]
# len to explore 6
# good_neighbour: [-26, 6]
# len to explore 6
# good_neighbour: [33, 14]
# good_neighbour: [34, 14]
# len to explore 7
# len to explore 6
# good_neighbour: [-25, 6]
# good_neighbour: [-27, 5]
# len to explore 7
# good_neighbour: [-26, 5]
# len to explore 7
# len to explore 6
# good_neighbour: [33, 13]
# good_neighbour: [34, 13]
# len to explore 7
# len to explore 6
# good_neighbour: [-27, 4]
# len to explore 6
# good_neighbour: [-26, 4]
# len to explore 6
# good_neighbour: [-28, 3]
# len to explore 6
# good_neighbour: [33, 12]
# len to explore 6
# good_neighbour: [32, 11]
# len to explore 6
# good_neighbour: [-27, 3]
# len to explore 6
# good_neighbour: [-28, 2]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 11]
# len to explore 5
# good_neighbour: [32, 10]
# good_neighbour: [33, 10]
# len to explore 6
# good_neighbour: [-29, 1]
# len to explore 6
# good_neighbour: [-28, 1]
# len to explore 6
# len to explore 5
# good_neighbour: [32, 9]
# good_neighbour: [33, 9]
# len to explore 6
# len to explore 5
# good_neighbour: [-29, 0]
# len to explore 5
# good_neighbour: [-30, -1]
# len to explore 5
# good_neighbour: [32, 8]
# good_neighbour: [33, 8]
# len to explore 6
# good_neighbour: [31, 7]
# len to explore 6
# good_neighbour: [-29, -1]
# len to explore 6
# good_neighbour: [-30, -2]
# len to explore 6
# good_neighbour: [32, 7]
# len to explore 6
# good_neighbour: [31, 6]
# len to explore 6
# good_neighbour: [32, 6]
# len to explore 6
# good_neighbour: [-31, -3]
# len to explore 6
# good_neighbour: [-30, -3]
# len to explore 6
# len to explore 5
# good_neighbour: [31, 5]
# good_neighbour: [32, 5]
# len to explore 6
# good_neighbour: [30, 4]
# len to explore 6
# good_neighbour: [-31, -4]
# good_neighbour: [-30, -4]
# len to explore 7
# good_neighbour: [-32, -5]
# len to explore 7
# good_neighbour: [31, 4]
# len to explore 7
# good_neighbour: [30, 3]
# len to explore 7
# good_neighbour: [31, 3]
# len to explore 7
# good_neighbour: [-31, -5]
# len to explore 7
# good_neighbour: [-32, -6]
# len to explore 7
# good_neighbour: [-31, -6]
# len to explore 7
# len to explore 6
# good_neighbour: [30, 2]
# len to explore 6
# good_neighbour: [29, 1]
# len to explore 6
# len to explore 5
# good_neighbour: [-32, -7]
# good_neighbour: [-31, -7]
# len to explore 6
# good_neighbour: [-33, -8]
# len to explore 6
# good_neighbour: [30, 1]
# len to explore 6
# good_neighbour: [29, 0]
# len to explore 6
# good_neighbour: [-32, -8]
# len to explore 6
# good_neighbour: [-33, -9]
# len to explore 6
# good_neighbour: [-32, -9]
# len to explore 6
# good_neighbour: [28, -1]
# len to explore 6
# good_neighbour: [29, -1]
# len to explore 6
# len to explore 5
# good_neighbour: [-33, -10]
# good_neighbour: [-32, -10]
# len to explore 6
# len to explore 5
# good_neighbour: [28, -2]
# len to explore 5
# good_neighbour: [27, -3]
# len to explore 5
# good_neighbour: [-33, -11]
# good_neighbour: [-32, -11]
# len to explore 6
# len to explore 5
# good_neighbour: [28, -3]
# good_neighbour: [26, -4]
# len to explore 6
# good_neighbour: [27, -4]
# len to explore 6
# good_neighbour: [-33, -12]
# len to explore 6
# good_neighbour: [-34, -13]
# len to explore 6
# good_neighbour: [26, -5]
# len to explore 6
# good_neighbour: [27, -5]
# len to explore 6
# good_neighbour: [25, -6]
# len to explore 6
# good_neighbour: [-33, -13]
# len to explore 6
# good_neighbour: [-34, -14]
# good_neighbour: [-33, -14]
# len to explore 7
# good_neighbour: [26, -6]
# good_neighbour: [24, -7]
# len to explore 8
# good_neighbour: [25, -7]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [-34, -15]
# good_neighbour: [-33, -15]
# len to explore 7
# len to explore 6
# good_neighbour: [24, -8]
# len to explore 6
# good_neighbour: [25, -8]
# len to explore 6
# good_neighbour: [23, -9]
# len to explore 6
# good_neighbour: [-34, -16]
# good_neighbour: [-33, -16]
# len to explore 7
# len to explore 6
# good_neighbour: [24, -9]
# good_neighbour: [22, -10]
# len to explore 7
# good_neighbour: [23, -10]
# len to explore 7
# good_neighbour: [21, -11]
# len to explore 7
# good_neighbour: [-34, -17]
# good_neighbour: [-33, -17]
# len to explore 8
# len to explore 7
# good_neighbour: [22, -11]
# len to explore 7
# len to explore 6
# good_neighbour: [21, -12]
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -18]
# good_neighbour: [-33, -18]
# len to explore 6
# len to explore 5
# good_neighbour: [20, -13]
# len to explore 5
# good_neighbour: [21, -13]
# good_neighbour: [19, -14]
# len to explore 6
# good_neighbour: [-34, -19]
# good_neighbour: [-33, -19]
# len to explore 7
# len to explore 6
# good_neighbour: [20, -14]
# good_neighbour: [18, -15]
# len to explore 7
# good_neighbour: [19, -15]
# len to explore 7
# good_neighbour: [17, -16]
# len to explore 7
# good_neighbour: [-34, -20]
# good_neighbour: [-33, -20]
# len to explore 8
# len to explore 7
# good_neighbour: [18, -16]
# len to explore 7
# good_neighbour: [16, -17]
# len to explore 7
# good_neighbour: [17, -17]
# len to explore 7
# good_neighbour: [15, -18]
# len to explore 7
# good_neighbour: [-34, -21]
# good_neighbour: [-33, -21]
# len to explore 8
# good_neighbour: [-32, -21]
# len to explore 8
# good_neighbour: [16, -18]
# len to explore 8
# good_neighbour: [14, -19]
# len to explore 8
# good_neighbour: [15, -19]
# len to explore 8
# good_neighbour: [13, -20]
# len to explore 8
# good_neighbour: [-33, -22]
# len to explore 8
# good_neighbour: [-32, -22]
# len to explore 8
# len to explore 7
# good_neighbour: [14, -20]
# len to explore 7
# good_neighbour: [12, -21]
# len to explore 7
# good_neighbour: [13, -21]
# len to explore 7
# good_neighbour: [11, -22]
# len to explore 7
# good_neighbour: [-33, -23]
# good_neighbour: [-32, -23]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [11, -21]
# good_neighbour: [10, -23]
# len to explore 7
# len to explore 6
# good_neighbour: [10, -22]
# good_neighbour: [9, -24]
# len to explore 7
# good_neighbour: [-33, -24]
# good_neighbour: [-32, -24]
# len to explore 8
# good_neighbour: [-31, -24]
# len to explore 8
# good_neighbour: [9, -23]
# len to explore 8
# good_neighbour: [8, -25]
# len to explore 8
# good_neighbour: [8, -24]
# len to explore 8
# len to explore 7
# good_neighbour: [-33, -25]
# good_neighbour: [-32, -25]
# len to explore 8
# good_neighbour: [-31, -25]
# len to explore 8
# len to explore 7
# good_neighbour: [7, -25]
# len to explore 7
# good_neighbour: [7, -24]
# len to explore 7
# good_neighbour: [6, -26]
# len to explore 7
# good_neighbour: [-32, -26]
# len to explore 7
# good_neighbour: [-31, -26]
# len to explore 7
# good_neighbour: [-30, -26]
# len to explore 7
# good_neighbour: [6, -25]
# good_neighbour: [5, -27]
# len to explore 8
# good_neighbour: [5, -26]
# len to explore 8
# len to explore 7
# good_neighbour: [-32, -27]
# good_neighbour: [-31, -27]
# len to explore 8
# good_neighbour: [-30, -27]
# len to explore 8
# len to explore 7
# good_neighbour: [4, -27]
# len to explore 7
# good_neighbour: [4, -26]
# len to explore 7
# good_neighbour: [3, -28]
# len to explore 7
# good_neighbour: [-31, -28]
# len to explore 7
# good_neighbour: [-30, -28]
# len to explore 7
# good_neighbour: [-29, -28]
# len to explore 7
# good_neighbour: [3, -27]
# len to explore 7
# good_neighbour: [2, -28]
# len to explore 7
# len to explore 6
# good_neighbour: [-30, -29]
# len to explore 6
# good_neighbour: [-29, -29]
# len to explore 6
# good_neighbour: [-28, -29]
# len to explore 6
# good_neighbour: [1, -29]
# len to explore 6
# good_neighbour: [1, -28]
# len to explore 6
# good_neighbour: [-29, -30]
# len to explore 6
# good_neighbour: [-28, -30]
# len to explore 6
# good_neighbour: [-27, -30]
# len to explore 6
# good_neighbour: [0, -29]
# len to explore 6
# good_neighbour: [-1, -30]
# len to explore 6
# good_neighbour: [-28, -31]
# len to explore 6
# good_neighbour: [-27, -31]
# good_neighbour: [-26, -30]
# len to explore 7
# good_neighbour: [-26, -31]
# len to explore 7
# good_neighbour: [-1, -29]
# len to explore 7
# good_neighbour: [-2, -30]
# len to explore 7
# good_neighbour: [-27, -32]
# len to explore 7
# good_neighbour: [-26, -32]
# good_neighbour: [-25, -31]
# len to explore 8
# len to explore 7
# good_neighbour: [-25, -32]
# good_neighbour: [-24, -31]
# len to explore 8
# good_neighbour: [-3, -31]
# len to explore 8
# good_neighbour: [-3, -30]
# len to explore 8
# len to explore 7
# good_neighbour: [-25, -33]
# good_neighbour: [-24, -32]
# len to explore 8
# len to explore 7
# good_neighbour: [-24, -33]
# good_neighbour: [-23, -32]
# len to explore 8
# len to explore 7
# good_neighbour: [-4, -31]
# good_neighbour: [-4, -30]
# len to explore 8
# good_neighbour: [-5, -32]
# len to explore 8
# good_neighbour: [-23, -33]
# len to explore 8
# good_neighbour: [-22, -32]
# len to explore 8
# good_neighbour: [-22, -33]
# len to explore 8
# good_neighbour: [-21, -32]
# len to explore 8
# good_neighbour: [-5, -31]
# len to explore 8
# good_neighbour: [-6, -32]
# len to explore 8
# good_neighbour: [-6, -31]
# len to explore 8
# good_neighbour: [-21, -33]
# len to explore 8
# len to explore 7
# good_neighbour: [-21, -34]
# good_neighbour: [-20, -33]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [-7, -32]
# good_neighbour: [-7, -31]
# len to explore 7
# good_neighbour: [-8, -33]
# len to explore 7
# good_neighbour: [-20, -34]
# good_neighbour: [-19, -33]
# len to explore 8
# good_neighbour: [-19, -34]
# len to explore 8
# good_neighbour: [-18, -33]
# len to explore 8
# good_neighbour: [-8, -32]
# len to explore 8
# good_neighbour: [-9, -33]
# len to explore 8
# good_neighbour: [-9, -32]
# len to explore 8
# good_neighbour: [-18, -34]
# len to explore 8
# good_neighbour: [-17, -33]
# len to explore 8
# good_neighbour: [-17, -34]
# len to explore 8
# good_neighbour: [-16, -33]
# len to explore 8
# len to explore 7
# good_neighbour: [-10, -33]
# good_neighbour: [-10, -32]
# len to explore 8
# len to explore 7
# good_neighbour: [-16, -34]
# len to explore 7
# good_neighbour: [-15, -33]
# len to explore 7
# good_neighbour: [-15, -34]
# len to explore 7
# good_neighbour: [-14, -33]
# len to explore 7
# good_neighbour: [-11, -33]
# good_neighbour: [-11, -32]
# len to explore 8
# len to explore 7
# good_neighbour: [-14, -34]
# len to explore 7
# good_neighbour: [-13, -33]
# len to explore 7
# good_neighbour: [-13, -34]
# len to explore 7
# good_neighbour: [-12, -33]
# len to explore 7
# len to explore 6
# len to explore 5
# len to explore 4
# len to explore 3
# len to explore 2
# len to explore 1
# extended_solutions: [[12, 33], [13, 33], [11, 33], [11, 32], [13, 34], [14, 33], [12, 33], [14, 34], [15, 33], [10, 33], [10, 32], [15, 34], [16, 33], [16, 34], [17, 33], [9, 33], [9, 32], [17, 34], [18, 33], [18, 34], [19, 33], [8, 33], [8, 32], [7, 31], [19, 34], [20, 33], [20, 34], [21, 33], [7, 32], [6, 31], [6, 32], [21, 34], [21, 32], [22, 33], [22, 32], [23, 33], [5, 31], [5, 32], [4, 30], [23, 32], [24, 33], [24, 32], [25, 33], [4, 31], [3, 30], [3, 31], [24, 31], [25, 32], [25, 31], [26, 32], [2, 30], [1, 29], [26, 31], [27, 32], [26, 30], [27, 31], [1, 30], [0, 29], [27, 30], [28, 31], [28, 30], [-1, 28], [-1, 29], [28, 29], [29, 30], [29, 29], [-2, 28], [-3, 27], [29, 28], [30, 29], [30, 28], [-3, 28], [-4, 26], [-4, 27], [30, 27], [31, 28], [31, 27], [-5, 26], [-5, 27], [-6, 25], [30, 26], [31, 26], [32, 27], [32, 26], [-6, 26], [-7, 24], [-7, 25], [31, 25], [32, 25], [33, 25], [-8, 24], [-8, 25], [-9, 23], [31, 24], [32, 24], [33, 24], [-9, 24], [-10, 22], [-10, 23], [-11, 21], [32, 23], [33, 23], [-11, 22], [-12, 21], [32, 22], [33, 22], [-13, 20], [-13, 21], [-14, 19], [32, 21], [33, 21], [34, 21], [-14, 20], [-15, 18], [-15, 19], [-16, 17], [33, 20], [34, 20], [-16, 18], [-17, 16], [-17, 17], [-18, 15], [33, 19], [34, 19], [-18, 16], [-19, 14], [-19, 15], [-20, 13], [33, 18], [34, 18], [-20, 14], [-21, 12], [-21, 13], [-22, 11], [33, 17], [34, 17], [-21, 11], [-23, 10], [-22, 10], [-24, 9], [33, 16], [34, 16], [-23, 9], [-25, 8], [-24, 8], [33, 15], [34, 15], [-25, 7], [-24, 7], [-26, 6], [33, 14], [34, 14], [-25, 6], [-27, 5], [-26, 5], [33, 13], [34, 13], [-27, 4], [-26, 4], [-28, 3], [33, 12], [32, 11], [-27, 3], [-28, 2], [33, 11], [32, 10], [33, 10], [-29, 1], [-28, 1], [32, 9], [33, 9], [-29, 0], [-30, -1], [32, 8], [33, 8], [31, 7], [-29, -1], [-30, -2], [32, 7], [31, 6], [32, 6], [-31, -3], [-30, -3], [31, 5], [32, 5], [30, 4], [-31, -4], [-30, -4], [-32, -5], [31, 4], [30, 3], [31, 3], [-31, -5], [-32, -6], [-31, -6], [30, 2], [29, 1], [-32, -7], [-31, -7], [-33, -8], [30, 1], [29, 0], [-32, -8], [-33, -9], [-32, -9], [28, -1], [29, -1], [-33, -10], [-32, -10], [28, -2], [27, -3], [-33, -11], [-32, -11], [28, -3], [26, -4], [27, -4], [-33, -12], [-34, -13], [26, -5], [27, -5], [25, -6], [-33, -13], [-34, -14], [-33, -14], [26, -6], [24, -7], [25, -7], [-34, -15], [-33, -15], [24, -8], [25, -8], [23, -9], [-34, -16], [-33, -16], [24, -9], [22, -10], [23, -10], [21, -11], [-34, -17], [-33, -17], [22, -11], [21, -12], [-34, -18], [-33, -18], [20, -13], [21, -13], [19, -14], [-34, -19], [-33, -19], [20, -14], [18, -15], [19, -15], [17, -16], [-34, -20], [-33, -20], [18, -16], [16, -17], [17, -17], [15, -18], [-34, -21], [-33, -21], [-32, -21], [16, -18], [14, -19], [15, -19], [13, -20], [-33, -22], [-32, -22], [14, -20], [12, -21], [13, -21], [11, -22], [-33, -23], [-32, -23], [11, -21], [10, -23], [10, -22], [9, -24], [-33, -24], [-32, -24], [-31, -24], [9, -23], [8, -25], [8, -24], [-33, -25], [-32, -25], [-31, -25], [7, -25], [7, -24], [6, -26], [-32, -26], [-31, -26], [-30, -26], [6, -25], [5, -27], [5, -26], [-32, -27], [-31, -27], [-30, -27], [4, -27], [4, -26], [3, -28], [-31, -28], [-30, -28], [-29, -28], [3, -27], [2, -28], [-30, -29], [-29, -29], [-28, -29], [1, -29], [1, -28], [-29, -30], [-28, -30], [-27, -30], [0, -29], [-1, -30], [-28, -31], [-27, -31], [-26, -30], [-26, -31], [-1, -29], [-2, -30], [-27, -32], [-26, -32], [-25, -31], [-25, -32], [-24, -31], [-3, -31], [-3, -30], [-25, -33], [-24, -32], [-24, -33], [-23, -32], [-4, -31], [-4, -30], [-5, -32], [-23, -33], [-22, -32], [-22, -33], [-21, -32], [-5, -31], [-6, -32], [-6, -31], [-21, -33], [-21, -34], [-20, -33], [-7, -32], [-7, -31], [-8, -33], [-20, -34], [-19, -33], [-19, -34], [-18, -33], [-8, -32], [-9, -33], [-9, -32], [-18, -34], [-17, -33], [-17, -34], [-16, -33], [-10, -33], [-10, -32], [-16, -34], [-15, -33], [-15, -34], [-14, -33], [-11, -33], [-11, -32], [-14, -34], [-13, -33], [-13, -34], [-12, -33]]
# good_neighbour: [29, 30]
# good_neighbour: [28, 31]
# good_neighbour: [27, 30]
# good_neighbour: [28, 29]
# good_neighbour: [29, 29]
# good_neighbour: [27, 31]
# len to explore 7
# good_neighbour: [28, 30]
# good_neighbour: [30, 29]
# len to explore 8
# good_neighbour: [27, 32]
# len to explore 8
# good_neighbour: [26, 30]
# good_neighbour: [26, 31]
# len to explore 9
# good_neighbour: [29, 28]
# len to explore 9
# good_neighbour: [30, 28]
# len to explore 9
# good_neighbour: [26, 32]
# len to explore 9
# len to explore 8
# good_neighbour: [31, 28]
# len to explore 8
# len to explore 7
# good_neighbour: [25, 31]
# len to explore 7
# good_neighbour: [25, 32]
# len to explore 7
# good_neighbour: [30, 27]
# len to explore 7
# good_neighbour: [31, 27]
# len to explore 7
# good_neighbour: [25, 33]
# len to explore 7
# good_neighbour: [32, 27]
# len to explore 7
# good_neighbour: [24, 31]
# good_neighbour: [24, 32]
# len to explore 8
# good_neighbour: [24, 33]
# len to explore 8
# good_neighbour: [30, 26]
# good_neighbour: [31, 26]
# len to explore 9
# good_neighbour: [32, 26]
# len to explore 9
# len to explore 8
# len to explore 7
# good_neighbour: [23, 32]
# len to explore 7
# good_neighbour: [23, 33]
# len to explore 7
# len to explore 6
# good_neighbour: [31, 25]
# len to explore 6
# good_neighbour: [32, 25]
# len to explore 6
# good_neighbour: [33, 25]
# len to explore 6
# good_neighbour: [22, 32]
# good_neighbour: [22, 33]
# len to explore 7
# len to explore 6
# good_neighbour: [31, 24]
# good_neighbour: [32, 24]
# len to explore 7
# good_neighbour: [33, 24]
# len to explore 7
# len to explore 6
# good_neighbour: [21, 32]
# good_neighbour: [21, 33]
# len to explore 7
# good_neighbour: [21, 34]
# len to explore 7
# good_neighbour: [32, 23]
# len to explore 7
# good_neighbour: [33, 23]
# len to explore 7
# len to explore 6
# good_neighbour: [20, 33]
# len to explore 6
# good_neighbour: [20, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [32, 22]
# good_neighbour: [33, 22]
# len to explore 6
# len to explore 5
# good_neighbour: [19, 33]
# good_neighbour: [19, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [32, 21]
# good_neighbour: [33, 21]
# len to explore 6
# good_neighbour: [34, 21]
# len to explore 6
# good_neighbour: [18, 33]
# good_neighbour: [18, 34]
# len to explore 7
# len to explore 6
# good_neighbour: [33, 20]
# len to explore 6
# good_neighbour: [34, 20]
# len to explore 6
# len to explore 5
# good_neighbour: [17, 33]
# good_neighbour: [17, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 19]
# good_neighbour: [34, 19]
# len to explore 6
# len to explore 5
# good_neighbour: [16, 33]
# good_neighbour: [16, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 18]
# good_neighbour: [34, 18]
# len to explore 6
# len to explore 5
# good_neighbour: [15, 33]
# good_neighbour: [15, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 17]
# good_neighbour: [34, 17]
# len to explore 6
# len to explore 5
# good_neighbour: [14, 33]
# good_neighbour: [14, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 16]
# good_neighbour: [34, 16]
# len to explore 6
# len to explore 5
# good_neighbour: [13, 33]
# good_neighbour: [13, 34]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 15]
# good_neighbour: [34, 15]
# len to explore 6
# len to explore 5
# good_neighbour: [12, 33]
# len to explore 5
# good_neighbour: [11, 32]
# len to explore 5
# good_neighbour: [33, 14]
# good_neighbour: [34, 14]
# len to explore 6
# len to explore 5
# good_neighbour: [11, 33]
# len to explore 5
# good_neighbour: [10, 32]
# good_neighbour: [10, 33]
# len to explore 6
# good_neighbour: [33, 13]
# good_neighbour: [34, 13]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [9, 32]
# good_neighbour: [9, 33]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 12]
# len to explore 5
# good_neighbour: [32, 11]
# len to explore 5
# good_neighbour: [8, 32]
# good_neighbour: [8, 33]
# len to explore 6
# good_neighbour: [7, 31]
# len to explore 6
# good_neighbour: [33, 11]
# len to explore 6
# good_neighbour: [32, 10]
# good_neighbour: [33, 10]
# len to explore 7
# good_neighbour: [7, 32]
# len to explore 7
# good_neighbour: [6, 31]
# len to explore 7
# good_neighbour: [6, 32]
# len to explore 7
# len to explore 6
# good_neighbour: [32, 9]
# good_neighbour: [33, 9]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [5, 31]
# good_neighbour: [5, 32]
# len to explore 6
# good_neighbour: [4, 30]
# len to explore 6
# good_neighbour: [32, 8]
# good_neighbour: [33, 8]
# len to explore 7
# good_neighbour: [31, 7]
# len to explore 7
# good_neighbour: [4, 31]
# len to explore 7
# good_neighbour: [3, 30]
# len to explore 7
# good_neighbour: [3, 31]
# len to explore 7
# good_neighbour: [32, 7]
# len to explore 7
# good_neighbour: [31, 6]
# len to explore 7
# good_neighbour: [32, 6]
# len to explore 7
# len to explore 6
# good_neighbour: [2, 30]
# len to explore 6
# good_neighbour: [1, 29]
# len to explore 6
# len to explore 5
# good_neighbour: [31, 5]
# good_neighbour: [32, 5]
# len to explore 6
# good_neighbour: [30, 4]
# len to explore 6
# good_neighbour: [1, 30]
# len to explore 6
# good_neighbour: [0, 29]
# len to explore 6
# good_neighbour: [31, 4]
# len to explore 6
# good_neighbour: [30, 3]
# len to explore 6
# good_neighbour: [31, 3]
# len to explore 6
# good_neighbour: [-1, 28]
# len to explore 6
# good_neighbour: [-1, 29]
# len to explore 6
# len to explore 5
# good_neighbour: [30, 2]
# len to explore 5
# good_neighbour: [29, 1]
# len to explore 5
# good_neighbour: [-2, 28]
# len to explore 5
# good_neighbour: [-3, 27]
# len to explore 5
# good_neighbour: [30, 1]
# len to explore 5
# good_neighbour: [29, 0]
# len to explore 5
# good_neighbour: [-3, 28]
# good_neighbour: [-4, 26]
# len to explore 6
# good_neighbour: [-4, 27]
# len to explore 6
# good_neighbour: [28, -1]
# len to explore 6
# good_neighbour: [29, -1]
# len to explore 6
# good_neighbour: [-5, 26]
# len to explore 6
# good_neighbour: [-5, 27]
# len to explore 6
# good_neighbour: [-6, 25]
# len to explore 6
# good_neighbour: [28, -2]
# len to explore 6
# good_neighbour: [27, -3]
# len to explore 6
# good_neighbour: [-6, 26]
# good_neighbour: [-7, 24]
# len to explore 7
# good_neighbour: [-7, 25]
# len to explore 7
# len to explore 6
# good_neighbour: [28, -3]
# good_neighbour: [26, -4]
# len to explore 7
# good_neighbour: [27, -4]
# len to explore 7
# good_neighbour: [-8, 24]
# len to explore 7
# good_neighbour: [-8, 25]
# len to explore 7
# good_neighbour: [-9, 23]
# len to explore 7
# good_neighbour: [26, -5]
# len to explore 7
# good_neighbour: [27, -5]
# len to explore 7
# good_neighbour: [25, -6]
# len to explore 7
# good_neighbour: [-9, 24]
# good_neighbour: [-10, 22]
# len to explore 8
# good_neighbour: [-10, 23]
# len to explore 8
# good_neighbour: [-11, 21]
# len to explore 8
# good_neighbour: [26, -6]
# good_neighbour: [24, -7]
# len to explore 9
# good_neighbour: [25, -7]
# len to explore 9
# len to explore 8
# good_neighbour: [-11, 22]
# len to explore 8
# len to explore 7
# good_neighbour: [-12, 21]
# len to explore 7
# len to explore 6
# good_neighbour: [24, -8]
# len to explore 6
# good_neighbour: [25, -8]
# len to explore 6
# good_neighbour: [23, -9]
# len to explore 6
# good_neighbour: [-13, 20]
# len to explore 6
# good_neighbour: [-13, 21]
# good_neighbour: [-14, 19]
# len to explore 7
# good_neighbour: [24, -9]
# good_neighbour: [22, -10]
# len to explore 8
# good_neighbour: [23, -10]
# len to explore 8
# good_neighbour: [21, -11]
# len to explore 8
# good_neighbour: [-14, 20]
# good_neighbour: [-15, 18]
# len to explore 9
# good_neighbour: [-15, 19]
# len to explore 9
# good_neighbour: [-16, 17]
# len to explore 9
# good_neighbour: [22, -11]
# len to explore 9
# len to explore 8
# good_neighbour: [21, -12]
# len to explore 8
# len to explore 7
# good_neighbour: [-16, 18]
# len to explore 7
# good_neighbour: [-17, 16]
# len to explore 7
# good_neighbour: [-17, 17]
# len to explore 7
# good_neighbour: [-18, 15]
# len to explore 7
# good_neighbour: [20, -13]
# len to explore 7
# good_neighbour: [21, -13]
# good_neighbour: [19, -14]
# len to explore 8
# good_neighbour: [-18, 16]
# len to explore 8
# good_neighbour: [-19, 14]
# len to explore 8
# good_neighbour: [-19, 15]
# len to explore 8
# good_neighbour: [-20, 13]
# len to explore 8
# good_neighbour: [20, -14]
# good_neighbour: [18, -15]
# len to explore 9
# good_neighbour: [19, -15]
# len to explore 9
# good_neighbour: [17, -16]
# len to explore 9
# good_neighbour: [-20, 14]
# len to explore 9
# good_neighbour: [-21, 12]
# len to explore 9
# good_neighbour: [-21, 13]
# len to explore 9
# good_neighbour: [-22, 11]
# len to explore 9
# good_neighbour: [18, -16]
# len to explore 9
# good_neighbour: [16, -17]
# len to explore 9
# good_neighbour: [17, -17]
# len to explore 9
# good_neighbour: [15, -18]
# len to explore 9
# len to explore 8
# good_neighbour: [-21, 11]
# good_neighbour: [-23, 10]
# len to explore 9
# len to explore 8
# good_neighbour: [-22, 10]
# good_neighbour: [-24, 9]
# len to explore 9
# good_neighbour: [16, -18]
# len to explore 9
# good_neighbour: [14, -19]
# len to explore 9
# good_neighbour: [15, -19]
# len to explore 9
# good_neighbour: [13, -20]
# len to explore 9
# good_neighbour: [-23, 9]
# len to explore 9
# good_neighbour: [-25, 8]
# len to explore 9
# good_neighbour: [-24, 8]
# len to explore 9
# len to explore 8
# good_neighbour: [14, -20]
# len to explore 8
# good_neighbour: [12, -21]
# len to explore 8
# good_neighbour: [13, -21]
# len to explore 8
# good_neighbour: [11, -22]
# len to explore 8
# good_neighbour: [-25, 7]
# len to explore 8
# good_neighbour: [-24, 7]
# len to explore 8
# good_neighbour: [-26, 6]
# len to explore 8
# len to explore 7
# good_neighbour: [11, -21]
# good_neighbour: [10, -23]
# len to explore 8
# len to explore 7
# good_neighbour: [10, -22]
# good_neighbour: [9, -24]
# len to explore 8
# good_neighbour: [-25, 6]
# good_neighbour: [-27, 5]
# len to explore 9
# good_neighbour: [-26, 5]
# len to explore 9
# len to explore 8
# good_neighbour: [9, -23]
# len to explore 8
# good_neighbour: [8, -25]
# len to explore 8
# good_neighbour: [8, -24]
# len to explore 8
# len to explore 7
# good_neighbour: [-27, 4]
# len to explore 7
# good_neighbour: [-26, 4]
# len to explore 7
# good_neighbour: [-28, 3]
# len to explore 7
# good_neighbour: [7, -25]
# len to explore 7
# good_neighbour: [7, -24]
# len to explore 7
# good_neighbour: [6, -26]
# len to explore 7
# good_neighbour: [-27, 3]
# len to explore 7
# good_neighbour: [-28, 2]
# len to explore 7
# len to explore 6
# good_neighbour: [6, -25]
# good_neighbour: [5, -27]
# len to explore 7
# good_neighbour: [5, -26]
# len to explore 7
# len to explore 6
# good_neighbour: [-29, 1]
# len to explore 6
# good_neighbour: [-28, 1]
# len to explore 6
# good_neighbour: [4, -27]
# len to explore 6
# good_neighbour: [4, -26]
# len to explore 6
# good_neighbour: [3, -28]
# len to explore 6
# good_neighbour: [-29, 0]
# len to explore 6
# good_neighbour: [-30, -1]
# len to explore 6
# good_neighbour: [3, -27]
# len to explore 6
# good_neighbour: [2, -28]
# len to explore 6
# len to explore 5
# good_neighbour: [-29, -1]
# len to explore 5
# good_neighbour: [-30, -2]
# len to explore 5
# good_neighbour: [1, -29]
# len to explore 5
# good_neighbour: [1, -28]
# len to explore 5
# good_neighbour: [-31, -3]
# len to explore 5
# good_neighbour: [-30, -3]
# len to explore 5
# good_neighbour: [0, -29]
# len to explore 5
# good_neighbour: [-1, -30]
# len to explore 5
# good_neighbour: [-31, -4]
# good_neighbour: [-30, -4]
# len to explore 6
# good_neighbour: [-32, -5]
# len to explore 6
# good_neighbour: [-1, -29]
# len to explore 6
# good_neighbour: [-2, -30]
# len to explore 6
# good_neighbour: [-31, -5]
# len to explore 6
# good_neighbour: [-32, -6]
# len to explore 6
# good_neighbour: [-31, -6]
# len to explore 6
# good_neighbour: [-3, -31]
# len to explore 6
# good_neighbour: [-3, -30]
# len to explore 6
# len to explore 5
# good_neighbour: [-32, -7]
# good_neighbour: [-31, -7]
# len to explore 6
# good_neighbour: [-33, -8]
# len to explore 6
# good_neighbour: [-4, -31]
# good_neighbour: [-4, -30]
# len to explore 7
# good_neighbour: [-5, -32]
# len to explore 7
# good_neighbour: [-32, -8]
# len to explore 7
# good_neighbour: [-33, -9]
# len to explore 7
# good_neighbour: [-32, -9]
# len to explore 7
# good_neighbour: [-5, -31]
# len to explore 7
# good_neighbour: [-6, -32]
# len to explore 7
# good_neighbour: [-6, -31]
# len to explore 7
# len to explore 6
# good_neighbour: [-33, -10]
# good_neighbour: [-32, -10]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [-7, -32]
# good_neighbour: [-7, -31]
# len to explore 6
# good_neighbour: [-8, -33]
# len to explore 6
# good_neighbour: [-33, -11]
# good_neighbour: [-32, -11]
# len to explore 7
# len to explore 6
# good_neighbour: [-8, -32]
# len to explore 6
# good_neighbour: [-9, -33]
# len to explore 6
# good_neighbour: [-9, -32]
# len to explore 6
# good_neighbour: [-33, -12]
# len to explore 6
# good_neighbour: [-34, -13]
# len to explore 6
# len to explore 5
# good_neighbour: [-10, -33]
# good_neighbour: [-10, -32]
# len to explore 6
# len to explore 5
# good_neighbour: [-33, -13]
# len to explore 5
# good_neighbour: [-34, -14]
# good_neighbour: [-33, -14]
# len to explore 6
# good_neighbour: [-11, -33]
# good_neighbour: [-11, -32]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -15]
# good_neighbour: [-33, -15]
# len to explore 6
# len to explore 5
# good_neighbour: [-12, -33]
# len to explore 5
# good_neighbour: [-13, -34]
# len to explore 5
# good_neighbour: [-34, -16]
# good_neighbour: [-33, -16]
# len to explore 6
# len to explore 5
# good_neighbour: [-13, -33]
# len to explore 5
# good_neighbour: [-14, -34]
# good_neighbour: [-14, -33]
# len to explore 6
# good_neighbour: [-34, -17]
# good_neighbour: [-33, -17]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [-15, -34]
# good_neighbour: [-15, -33]
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -18]
# good_neighbour: [-33, -18]
# len to explore 6
# len to explore 5
# good_neighbour: [-16, -34]
# good_neighbour: [-16, -33]
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -19]
# good_neighbour: [-33, -19]
# len to explore 6
# len to explore 5
# good_neighbour: [-17, -34]
# good_neighbour: [-17, -33]
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -20]
# good_neighbour: [-33, -20]
# len to explore 6
# len to explore 5
# good_neighbour: [-18, -34]
# good_neighbour: [-18, -33]
# len to explore 6
# len to explore 5
# good_neighbour: [-34, -21]
# good_neighbour: [-33, -21]
# len to explore 6
# good_neighbour: [-32, -21]
# len to explore 6
# good_neighbour: [-19, -34]
# good_neighbour: [-19, -33]
# len to explore 7
# len to explore 6
# good_neighbour: [-33, -22]
# len to explore 6
# good_neighbour: [-32, -22]
# len to explore 6
# len to explore 5
# good_neighbour: [-20, -34]
# good_neighbour: [-20, -33]
# len to explore 6
# len to explore 5
# good_neighbour: [-33, -23]
# good_neighbour: [-32, -23]
# len to explore 6
# len to explore 5
# good_neighbour: [-21, -34]
# good_neighbour: [-21, -33]
# len to explore 6
# good_neighbour: [-21, -32]
# len to explore 6
# good_neighbour: [-33, -24]
# good_neighbour: [-32, -24]
# len to explore 7
# good_neighbour: [-31, -24]
# len to explore 7
# good_neighbour: [-22, -33]
# len to explore 7
# good_neighbour: [-22, -32]
# len to explore 7
# len to explore 6
# good_neighbour: [-33, -25]
# good_neighbour: [-32, -25]
# len to explore 7
# good_neighbour: [-31, -25]
# len to explore 7
# len to explore 6
# good_neighbour: [-23, -33]
# good_neighbour: [-23, -32]
# len to explore 7
# len to explore 6
# good_neighbour: [-32, -26]
# len to explore 6
# good_neighbour: [-31, -26]
# len to explore 6
# good_neighbour: [-30, -26]
# len to explore 6
# good_neighbour: [-24, -33]
# good_neighbour: [-24, -32]
# len to explore 7
# good_neighbour: [-24, -31]
# len to explore 7
# good_neighbour: [-32, -27]
# good_neighbour: [-31, -27]
# len to explore 8
# good_neighbour: [-30, -27]
# len to explore 8
# len to explore 7
# good_neighbour: [-25, -33]
# good_neighbour: [-25, -32]
# len to explore 8
# good_neighbour: [-25, -31]
# len to explore 8
# len to explore 7
# good_neighbour: [-31, -28]
# len to explore 7
# good_neighbour: [-30, -28]
# len to explore 7
# good_neighbour: [-29, -28]
# len to explore 7
# good_neighbour: [-26, -32]
# len to explore 7
# good_neighbour: [-26, -31]
# len to explore 7
# good_neighbour: [-26, -30]
# len to explore 7
# good_neighbour: [-30, -29]
# len to explore 7
# good_neighbour: [-29, -29]
# len to explore 7
# good_neighbour: [-28, -29]
# len to explore 7
# good_neighbour: [-27, -32]
# good_neighbour: [-27, -31]
# len to explore 8
# good_neighbour: [-27, -30]
# len to explore 8
# len to explore 7
# good_neighbour: [-29, -30]
# len to explore 7
# good_neighbour: [-28, -30]
# len to explore 7
# len to explore 6
# good_neighbour: [-28, -31]
# len to explore 6
# len to explore 5
# len to explore 4
# len to explore 3
# len to explore 2
# len to explore 1
# extended_solutions: [[28, 30], [29, 30], [28, 31], [27, 30], [28, 29], [29, 29], [27, 31], [28, 30], [30, 29], [27, 32], [26, 30], [26, 31], [29, 28], [30, 28], [26, 32], [31, 28], [25, 31], [25, 32], [30, 27], [31, 27], [25, 33], [32, 27], [24, 31], [24, 32], [24, 33], [30, 26], [31, 26], [32, 26], [23, 32], [23, 33], [31, 25], [32, 25], [33, 25], [22, 32], [22, 33], [31, 24], [32, 24], [33, 24], [21, 32], [21, 33], [21, 34], [32, 23], [33, 23], [20, 33], [20, 34], [32, 22], [33, 22], [19, 33], [19, 34], [32, 21], [33, 21], [34, 21], [18, 33], [18, 34], [33, 20], [34, 20], [17, 33], [17, 34], [33, 19], [34, 19], [16, 33], [16, 34], [33, 18], [34, 18], [15, 33], [15, 34], [33, 17], [34, 17], [14, 33], [14, 34], [33, 16], [34, 16], [13, 33], [13, 34], [33, 15], [34, 15], [12, 33], [11, 32], [33, 14], [34, 14], [11, 33], [10, 32], [10, 33], [33, 13], [34, 13], [9, 32], [9, 33], [33, 12], [32, 11], [8, 32], [8, 33], [7, 31], [33, 11], [32, 10], [33, 10], [7, 32], [6, 31], [6, 32], [32, 9], [33, 9], [5, 31], [5, 32], [4, 30], [32, 8], [33, 8], [31, 7], [4, 31], [3, 30], [3, 31], [32, 7], [31, 6], [32, 6], [2, 30], [1, 29], [31, 5], [32, 5], [30, 4], [1, 30], [0, 29], [31, 4], [30, 3], [31, 3], [-1, 28], [-1, 29], [30, 2], [29, 1], [-2, 28], [-3, 27], [30, 1], [29, 0], [-3, 28], [-4, 26], [-4, 27], [28, -1], [29, -1], [-5, 26], [-5, 27], [-6, 25], [28, -2], [27, -3], [-6, 26], [-7, 24], [-7, 25], [28, -3], [26, -4], [27, -4], [-8, 24], [-8, 25], [-9, 23], [26, -5], [27, -5], [25, -6], [-9, 24], [-10, 22], [-10, 23], [-11, 21], [26, -6], [24, -7], [25, -7], [-11, 22], [-12, 21], [24, -8], [25, -8], [23, -9], [-13, 20], [-13, 21], [-14, 19], [24, -9], [22, -10], [23, -10], [21, -11], [-14, 20], [-15, 18], [-15, 19], [-16, 17], [22, -11], [21, -12], [-16, 18], [-17, 16], [-17, 17], [-18, 15], [20, -13], [21, -13], [19, -14], [-18, 16], [-19, 14], [-19, 15], [-20, 13], [20, -14], [18, -15], [19, -15], [17, -16], [-20, 14], [-21, 12], [-21, 13], [-22, 11], [18, -16], [16, -17], [17, -17], [15, -18], [-21, 11], [-23, 10], [-22, 10], [-24, 9], [16, -18], [14, -19], [15, -19], [13, -20], [-23, 9], [-25, 8], [-24, 8], [14, -20], [12, -21], [13, -21], [11, -22], [-25, 7], [-24, 7], [-26, 6], [11, -21], [10, -23], [10, -22], [9, -24], [-25, 6], [-27, 5], [-26, 5], [9, -23], [8, -25], [8, -24], [-27, 4], [-26, 4], [-28, 3], [7, -25], [7, -24], [6, -26], [-27, 3], [-28, 2], [6, -25], [5, -27], [5, -26], [-29, 1], [-28, 1], [4, -27], [4, -26], [3, -28], [-29, 0], [-30, -1], [3, -27], [2, -28], [-29, -1], [-30, -2], [1, -29], [1, -28], [-31, -3], [-30, -3], [0, -29], [-1, -30], [-31, -4], [-30, -4], [-32, -5], [-1, -29], [-2, -30], [-31, -5], [-32, -6], [-31, -6], [-3, -31], [-3, -30], [-32, -7], [-31, -7], [-33, -8], [-4, -31], [-4, -30], [-5, -32], [-32, -8], [-33, -9], [-32, -9], [-5, -31], [-6, -32], [-6, -31], [-33, -10], [-32, -10], [-7, -32], [-7, -31], [-8, -33], [-33, -11], [-32, -11], [-8, -32], [-9, -33], [-9, -32], [-33, -12], [-34, -13], [-10, -33], [-10, -32], [-33, -13], [-34, -14], [-33, -14], [-11, -33], [-11, -32], [-34, -15], [-33, -15], [-12, -33], [-13, -34], [-34, -16], [-33, -16], [-13, -33], [-14, -34], [-14, -33], [-34, -17], [-33, -17], [-15, -34], [-15, -33], [-34, -18], [-33, -18], [-16, -34], [-16, -33], [-34, -19], [-33, -19], [-17, -34], [-17, -33], [-34, -20], [-33, -20], [-18, -34], [-18, -33], [-34, -21], [-33, -21], [-32, -21], [-19, -34], [-19, -33], [-33, -22], [-32, -22], [-20, -34], [-20, -33], [-33, -23], [-32, -23], [-21, -34], [-21, -33], [-21, -32], [-33, -24], [-32, -24], [-31, -24], [-22, -33], [-22, -32], [-33, -25], [-32, -25], [-31, -25], [-23, -33], [-23, -32], [-32, -26], [-31, -26], [-30, -26], [-24, -33], [-24, -32], [-24, -31], [-32, -27], [-31, -27], [-30, -27], [-25, -33], [-25, -32], [-25, -31], [-31, -28], [-30, -28], [-29, -28], [-26, -32], [-26, -31], [-26, -30], [-30, -29], [-29, -29], [-28, -29], [-27, -32], [-27, -31], [-27, -30], [-29, -30], [-28, -30], [-28, -31]]
# good_neighbour: [13, 79]
# good_neighbour: [11, 79]
# good_neighbour: [11, 78]
# good_neighbour: [13, 80]
# good_neighbour: [10, 77]
# good_neighbour: [14, 81]
# len to explore 7
# good_neighbour: [12, 79]
# good_neighbour: [14, 80]
# good_neighbour: [15, 81]
# len to explore 9
# good_neighbour: [10, 78]
# good_neighbour: [9, 77]
# len to explore 10
# good_neighbour: [9, 76]
# len to explore 10
# good_neighbour: [15, 82]
# len to explore 10
# good_neighbour: [8, 75]
# len to explore 10
# good_neighbour: [16, 83]
# len to explore 10
# len to explore 9
# good_neighbour: [16, 82]
# len to explore 9
# good_neighbour: [17, 83]
# len to explore 9
# good_neighbour: [8, 76]
# len to explore 9
# good_neighbour: [7, 75]
# len to explore 9
# len to explore 8
# good_neighbour: [17, 84]
# len to explore 8
# good_neighbour: [7, 76]
# len to explore 8
# good_neighbour: [18, 85]
# len to explore 8
# good_neighbour: [18, 84]
# len to explore 8
# good_neighbour: [19, 85]
# len to explore 8
# good_neighbour: [6, 74]
# len to explore 8
# good_neighbour: [6, 75]
# good_neighbour: [5, 73]
# len to explore 9
# good_neighbour: [19, 86]
# len to explore 9
# good_neighbour: [5, 74]
# len to explore 9
# good_neighbour: [20, 87]
# len to explore 9
# good_neighbour: [20, 86]
# len to explore 9
# good_neighbour: [21, 87]
# len to explore 9
# len to explore 8
# good_neighbour: [4, 73]
# len to explore 8
# good_neighbour: [4, 74]
# len to explore 8
# good_neighbour: [21, 88]
# len to explore 8
# good_neighbour: [3, 72]
# len to explore 8
# good_neighbour: [22, 89]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [3, 73]
# len to explore 6
# good_neighbour: [2, 72]
# len to explore 6
# good_neighbour: [21, 89]
# good_neighbour: [23, 90]
# len to explore 7
# len to explore 6
# good_neighbour: [22, 90]
# good_neighbour: [24, 91]
# len to explore 7
# good_neighbour: [1, 71]
# len to explore 7
# good_neighbour: [1, 72]
# len to explore 7
# good_neighbour: [23, 91]
# len to explore 7
# good_neighbour: [25, 92]
# len to explore 7
# good_neighbour: [24, 92]
# len to explore 7
# len to explore 6
# good_neighbour: [0, 71]
# len to explore 6
# good_neighbour: [-1, 70]
# len to explore 6
# good_neighbour: [25, 93]
# len to explore 6
# good_neighbour: [24, 93]
# len to explore 6
# good_neighbour: [26, 94]
# len to explore 6
# good_neighbour: [-1, 71]
# len to explore 6
# good_neighbour: [-2, 70]
# len to explore 6
# good_neighbour: [25, 94]
# good_neighbour: [27, 95]
# len to explore 7
# good_neighbour: [26, 95]
# len to explore 7
# len to explore 6
# good_neighbour: [-3, 69]
# len to explore 6
# good_neighbour: [-3, 70]
# len to explore 6
# good_neighbour: [27, 96]
# len to explore 6
# good_neighbour: [26, 96]
# len to explore 6
# good_neighbour: [28, 97]
# len to explore 6
# good_neighbour: [-4, 69]
# good_neighbour: [-4, 70]
# len to explore 7
# good_neighbour: [-5, 68]
# len to explore 7
# good_neighbour: [27, 97]
# len to explore 7
# good_neighbour: [28, 98]
# len to explore 7
# len to explore 6
# good_neighbour: [-5, 69]
# len to explore 6
# good_neighbour: [-6, 68]
# len to explore 6
# good_neighbour: [-6, 69]
# len to explore 6
# good_neighbour: [29, 99]
# len to explore 6
# good_neighbour: [28, 99]
# len to explore 6
# len to explore 5
# good_neighbour: [-7, 68]
# good_neighbour: [-7, 69]
# len to explore 6
# good_neighbour: [-8, 67]
# len to explore 6
# good_neighbour: [29, 100]
# len to explore 6
# good_neighbour: [30, 101]
# len to explore 6
# good_neighbour: [-8, 68]
# len to explore 6
# good_neighbour: [-9, 67]
# len to explore 6
# good_neighbour: [-9, 68]
# len to explore 6
# good_neighbour: [29, 101]
# len to explore 6
# good_neighbour: [30, 102]
# len to explore 6
# len to explore 5
# good_neighbour: [-10, 67]
# good_neighbour: [-10, 68]
# len to explore 6
# len to explore 5
# good_neighbour: [31, 103]
# len to explore 5
# good_neighbour: [30, 103]
# len to explore 5
# good_neighbour: [-11, 67]
# good_neighbour: [-11, 68]
# len to explore 6
# len to explore 5
# good_neighbour: [31, 104]
# good_neighbour: [30, 104]
# len to explore 6
# good_neighbour: [32, 105]
# len to explore 6
# good_neighbour: [-12, 67]
# len to explore 6
# good_neighbour: [-13, 66]
# len to explore 6
# good_neighbour: [31, 105]
# len to explore 6
# good_neighbour: [32, 106]
# len to explore 6
# good_neighbour: [31, 106]
# len to explore 6
# good_neighbour: [-13, 67]
# len to explore 6
# good_neighbour: [-14, 66]
# good_neighbour: [-14, 67]
# len to explore 7
# len to explore 6
# good_neighbour: [32, 107]
# good_neighbour: [31, 107]
# len to explore 7
# good_neighbour: [33, 108]
# len to explore 7
# len to explore 6
# good_neighbour: [-15, 66]
# good_neighbour: [-15, 67]
# len to explore 7
# len to explore 6
# good_neighbour: [32, 108]
# len to explore 6
# good_neighbour: [33, 109]
# len to explore 6
# good_neighbour: [32, 109]
# len to explore 6
# good_neighbour: [-16, 66]
# good_neighbour: [-16, 67]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [33, 110]
# good_neighbour: [32, 110]
# len to explore 6
# len to explore 5
# good_neighbour: [-17, 66]
# good_neighbour: [-17, 67]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 111]
# good_neighbour: [32, 111]
# len to explore 6
# len to explore 5
# good_neighbour: [-18, 66]
# good_neighbour: [-18, 67]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 112]
# len to explore 5
# good_neighbour: [34, 113]
# len to explore 5
# good_neighbour: [-19, 66]
# good_neighbour: [-19, 67]
# len to explore 6
# len to explore 5
# good_neighbour: [33, 113]
# len to explore 5
# good_neighbour: [34, 114]
# good_neighbour: [33, 114]
# len to explore 6
# good_neighbour: [-20, 66]
# good_neighbour: [-20, 67]
# len to explore 7
# len to explore 6
# len to explore 5
# good_neighbour: [34, 115]
# good_neighbour: [33, 115]
# len to explore 6
# len to explore 5
# good_neighbour: [-21, 66]
# good_neighbour: [-21, 67]
# len to explore 6
# good_neighbour: [-21, 68]
# len to explore 6
# good_neighbour: [34, 116]
# good_neighbour: [33, 116]
# len to explore 7
# len to explore 6
# good_neighbour: [-22, 67]
# len to explore 6
# good_neighbour: [-22, 68]
# len to explore 6
# len to explore 5
# good_neighbour: [34, 117]
# good_neighbour: [33, 117]
# len to explore 6
# len to explore 5
# good_neighbour: [-23, 67]
# good_neighbour: [-23, 68]
# len to explore 6
# len to explore 5
# good_neighbour: [34, 118]
# good_neighbour: [33, 118]
# len to explore 6
# len to explore 5
# good_neighbour: [-24, 67]
# good_neighbour: [-24, 68]
# len to explore 6
# good_neighbour: [-24, 69]
# len to explore 6
# good_neighbour: [34, 119]
# good_neighbour: [33, 119]
# len to explore 7
# len to explore 6
# good_neighbour: [-25, 67]
# good_neighbour: [-25, 68]
# len to explore 7
# good_neighbour: [-25, 69]
# len to explore 7
# len to explore 6
# good_neighbour: [34, 120]
# good_neighbour: [33, 120]
# len to explore 7
# len to explore 6
# good_neighbour: [-26, 68]
# len to explore 6
# good_neighbour: [-26, 69]
# len to explore 6
# good_neighbour: [-26, 70]
# len to explore 6
# good_neighbour: [34, 121]
# good_neighbour: [33, 121]
# len to explore 7
# good_neighbour: [32, 121]
# len to explore 7
# good_neighbour: [-27, 68]
# good_neighbour: [-27, 69]
# len to explore 8
# good_neighbour: [-27, 70]
# len to explore 8
# len to explore 7
# good_neighbour: [33, 122]
# len to explore 7
# good_neighbour: [32, 122]
# len to explore 7
# len to explore 6
# good_neighbour: [-28, 69]
# len to explore 6
# good_neighbour: [-28, 70]
# len to explore 6
# good_neighbour: [-28, 71]
# len to explore 6
# good_neighbour: [33, 123]
# good_neighbour: [32, 123]
# len to explore 7
# len to explore 6
# good_neighbour: [-29, 70]
# len to explore 6
# good_neighbour: [-29, 71]
# len to explore 6
# good_neighbour: [-29, 72]
# len to explore 6
# good_neighbour: [33, 124]
# good_neighbour: [32, 124]
# len to explore 7
# good_neighbour: [31, 124]
# len to explore 7
# good_neighbour: [-30, 71]
# len to explore 7
# good_neighbour: [-30, 72]
# len to explore 7
# good_neighbour: [-30, 73]
# len to explore 7
# good_neighbour: [33, 125]
# good_neighbour: [32, 125]
# len to explore 8
# good_neighbour: [31, 125]
# len to explore 8
# len to explore 7
# good_neighbour: [-31, 72]
# len to explore 7
# good_neighbour: [-31, 73]
# len to explore 7
# good_neighbour: [-30, 74]
# good_neighbour: [-31, 74]
# len to explore 8
# good_neighbour: [32, 126]
# len to explore 8
# good_neighbour: [31, 126]
# len to explore 8
# good_neighbour: [30, 126]
# len to explore 8
# good_neighbour: [-32, 73]
# len to explore 8
# good_neighbour: [-32, 74]
# len to explore 8
# good_neighbour: [-31, 75]
# len to explore 8
# good_neighbour: [-32, 75]
# len to explore 8
# good_neighbour: [32, 127]
# good_neighbour: [31, 127]
# len to explore 9
# good_neighbour: [30, 127]
# len to explore 9
# len to explore 8
# len to explore 7
# good_neighbour: [-33, 75]
# len to explore 7
# good_neighbour: [-31, 76]
# good_neighbour: [-32, 76]
# len to explore 8
# ...
# len to explore 5
# len to explore 4
# good_neighbour: [98, 128]
# len to explore 4
# good_neighbour: [99, 128]
# len to explore 4
# good_neighbour: [99, 129]
# len to explore 4
# len to explore 3
# len to explore 2
# len to explore 1
# extended_solutions: [[71, 71], [72, 71], [71, 72], [70, 71], [71, 70], [72, 70], [70, 72], [71, 71], [73, 70], [70, 73], [69, 72], [72, 69], [73, 69], [74, 70], [69, 73], [74, 69], [70, 74], [69, 74], [68, 73], [73, 68], [74, 68], [75, 69], [68, 74], [75, 68], [76, 69], [69, 75], [68, 75], [75, 67], [76, 68], [67, 75], [76, 67], [77, 68], [69, 76], [68, 76], [67, 76], [77, 67], [78, 68], [78, 67], [79, 68], [68, 77], [67, 77], [79, 67], [79, 66], [80, 67], [68, 78], [67, 78], [80, 66], [81, 67], [81, 66], [82, 67], [68, 79], [67, 79], [66, 79], [82, 66], [83, 67], [83, 66], [84, 67], [67, 80], [66, 80], [84, 66], [85, 67], [85, 66], [86, 67], [67, 81], [66, 81], [86, 66], [87, 67], [87, 66], [88, 67], [67, 82], [66, 82], [89, 67], [89, 68], [90, 67], [67, 83], [66, 83], [90, 68], [91, 67], [91, 68], [92, 67], [67, 84], [66, 84], [92, 68], [93, 69], [93, 68], [94, 69], [67, 85], [66, 85], [94, 68], [95, 69], [95, 68], [96, 69], [67, 86], [66, 86], [96, 70], [97, 69], [97, 70], [67, 87], [66, 87], [98, 70], [99, 71], [99, 70], [67, 88], [68, 89], [100, 71], [101, 71], [101, 72], [67, 89], [68, 90], [67, 90], [102, 72], [103, 73], [103, 72], [68, 91], [67, 91], [104, 74], [104, 73], [105, 73], [105, 74], [68, 92], [67, 92], [69, 93], [106, 74], [106, 75], [107, 75], [107, 76], [68, 93], [69, 94], [68, 94], [108, 76], [108, 75], [109, 77], [109, 76], [69, 95], [68, 95], [70, 96], [110, 78], [110, 77], [111, 79], [111, 78], [69, 96], [70, 97], [69, 97], [112, 79], [113, 79], [113, 80], [70, 98], [71, 99], [114, 81], [114, 80], [115, 81], [115, 82], [70, 99], [71, 100], [116, 83], [116, 82], [117, 83], [117, 84], [72, 101], [71, 101], [118, 85], [118, 84], [119, 85], [119, 86], [72, 102], [73, 103], [120, 87], [120, 86], [121, 87], [121, 88], [72, 103], [74, 104], [73, 104], [122, 89], [121, 89], [123, 90], [74, 105], [73, 105], [75, 106], [122, 90], [124, 91], [123, 91], [125, 92], [74, 106], [76, 107], [75, 107], [124, 92], [125, 93], [124, 93], [76, 108], [75, 108], [77, 109], [126, 94], [125, 94], [127, 95], [126, 95], [76, 109], [78, 110], [77, 110], [79, 111], [127, 96], [126, 96], [128, 97], [78, 111], [79, 112], [127, 97], [128, 98], [80, 113], [79, 113], [81, 114], [129, 99], [128, 99], [80, 114], [82, 115], [81, 115], [83, 116], [82, 116], [84, 117], [83, 117], [85, 118], [84, 118], [86, 119], [85, 119], [87, 120], [86, 120], [88, 121], [87, 121], [89, 122], [89, 121], [90, 123], [90, 122], [91, 124], [91, 123], [92, 125], [92, 124], [93, 124], [93, 125], [94, 125], [94, 126], [95, 126], [95, 127], [96, 127], [96, 126], [97, 128], [97, 127], [98, 128], [99, 128], [99, 129]]
# good_neighbour: [99, 70]
# good_neighbour: [97, 70]
# good_neighbour: [97, 69]
# good_neighbour: [99, 71]
# len to explore 5
# good_neighbour: [98, 70]
# good_neighbour: [100, 71]
# good_neighbour: [101, 72]
# len to explore 7
# good_neighbour: [96, 70]
# good_neighbour: [96, 69]
# good_neighbour: [95, 68]
# len to explore 9
# len to explore 8
# good_neighbour: [101, 71]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [102, 72]
# good_neighbour: [103, 72]
# len to explore 7
# good_neighbour: [95, 69]
# good_neighbour: [94, 68]
# len to explore 8
# len to explore 7
# good_neighbour: [94, 69]
# len to explore 7
# good_neighbour: [103, 73]
# len to explore 7
# good_neighbour: [104, 74]
# len to explore 7
# good_neighbour: [104, 73]
# good_neighbour: [105, 74]
# len to explore 8
# len to explore 7
# good_neighbour: [93, 68]
# good_neighbour: [93, 69]
# len to explore 8
# good_neighbour: [92, 67]
# len to explore 8
# good_neighbour: [105, 73]
# len to explore 8
# good_neighbour: [106, 74]
# len to explore 8
# good_neighbour: [106, 75]
# len to explore 8
# good_neighbour: [107, 76]
# len to explore 8
# good_neighbour: [92, 68]
# len to explore 8
# good_neighbour: [91, 67]
# len to explore 8
# good_neighbour: [91, 68]
# len to explore 8
# good_neighbour: [107, 75]
# len to explore 8
# good_neighbour: [108, 76]
# len to explore 8
# good_neighbour: [108, 75]
# len to explore 8
# good_neighbour: [109, 76]
# len to explore 8
# len to explore 7
# good_neighbour: [90, 67]
# good_neighbour: [90, 68]
# len to explore 8
# len to explore 7
# good_neighbour: [109, 77]
# len to explore 7
# good_neighbour: [110, 78]
# len to explore 7
# good_neighbour: [110, 77]
# len to explore 7
# good_neighbour: [111, 78]
# len to explore 7
# good_neighbour: [89, 67]
# good_neighbour: [89, 68]
# len to explore 8
# len to explore 7
# good_neighbour: [111, 79]
# len to explore 7
# len to explore 6
# good_neighbour: [112, 79]
# len to explore 6
# good_neighbour: [113, 80]
# len to explore 6
# good_neighbour: [88, 67]
# len to explore 6
# good_neighbour: [87, 66]
# len to explore 6
# good_neighbour: [113, 79]
# len to explore 6
# good_neighbour: [114, 81]
# len to explore 6
# good_neighbour: [114, 80]
# good_neighbour: [115, 82]
# len to explore 7
# good_neighbour: [87, 67]
# len to explore 7
# good_neighbour: [86, 66]
# good_neighbour: [86, 67]
# len to explore 8
# good_neighbour: [115, 81]
# len to explore 8
# good_neighbour: [116, 83]
# len to explore 8
# good_neighbour: [116, 82]
# len to explore 8
# good_neighbour: [117, 84]
# len to explore 8
# len to explore 7
# good_neighbour: [85, 66]
# good_neighbour: [85, 67]
# len to explore 8
# len to explore 7
# good_neighbour: [117, 83]
# len to explore 7
# good_neighbour: [118, 85]
# len to explore 7
# good_neighbour: [118, 84]
# len to explore 7
# good_neighbour: [119, 86]
# len to explore 7
# good_neighbour: [84, 66]
# good_neighbour: [84, 67]
# len to explore 8
# len to explore 7
# good_neighbour: [119, 85]
# len to explore 7
# good_neighbour: [120, 87]
# len to explore 7
# good_neighbour: [120, 86]
# len to explore 7
# good_neighbour: [121, 88]
# len to explore 7
# good_neighbour: [83, 66]
# good_neighbour: [83, 67]
# len to explore 8
# len to explore 7
# good_neighbour: [121, 87]
# len to explore 7
# good_neighbour: [122, 89]
# len to explore 7
# len to explore 6
# good_neighbour: [121, 89]
# good_neighbour: [123, 90]
# len to explore 7
# good_neighbour: [82, 66]
# good_neighbour: [82, 67]
# len to explore 8
# len to explore 7
# len to explore 6
# good_neighbour: [122, 90]
# good_neighbour: [124, 91]
# len to explore 7
# good_neighbour: [123, 91]
# len to explore 7
# good_neighbour: [125, 92]
# len to explore 7
# good_neighbour: [81, 66]
# good_neighbour: [81, 67]
# len to explore 8
# len to explore 7
# good_neighbour: [124, 92]
# len to explore 7
# len to explore 6
# good_neighbour: [125, 93]
# len to explore 6
# good_neighbour: [124, 93]
# len to explore 6
# good_neighbour: [80, 66]
# good_neighbour: [80, 67]
# len to explore 7
# len to explore 6
# good_neighbour: [126, 94]
# len to explore 6
# good_neighbour: [125, 94]
# good_neighbour: [127, 95]
# len to explore 7
# good_neighbour: [126, 95]
# len to explore 7
# good_neighbour: [79, 66]
# good_neighbour: [79, 67]
# len to explore 8
# good_neighbour: [79, 68]
# len to explore 8
# len to explore 7
# good_neighbour: [127, 96]
# len to explore 7
# good_neighbour: [126, 96]
# len to explore 7
# good_neighbour: [128, 97]
# len to explore 7
# good_neighbour: [78, 67]
# len to explore 7
# good_neighbour: [78, 68]
# len to explore 7
# len to explore 6
# good_neighbour: [127, 97]
# len to explore 6
# good_neighbour: [128, 98]
# len to explore 6
# len to explore 5
# good_neighbour: [77, 67]
# good_neighbour: [77, 68]
# len to explore 6
# len to explore 5
# good_neighbour: [129, 99]
# len to explore 5
# good_neighbour: [128, 99]
# len to explore 5
# good_neighbour: [76, 67]
# good_neighbour: [76, 68]
# len to explore 6
# good_neighbour: [76, 69]
# len to explore 6
# len to explore 5
# len to explore 4
# good_neighbour: [75, 67]
# good_neighbour: [75, 68]
# len to explore 5
# good_neighbour: [75, 69]
# len to explore 5
# len to explore 4
# good_neighbour: [74, 68]
# len to explore 4
# good_neighbour: [74, 69]
# len to explore 4
# good_neighbour: [74, 70]
# len to explore 4
# good_neighbour: [73, 68]
# good_neighbour: [73, 69]
# len to explore 5
# good_neighbour: [73, 70]
# len to explore 5
# len to explore 4
# good_neighbour: [72, 69]
# len to explore 4
# good_neighbour: [72, 70]
# len to explore 4
# good_neighbour: [72, 71]
# len to explore 4
# good_neighbour: [71, 70]
# len to explore 4
# good_neighbour: [71, 71]
# len to explore 4
# good_neighbour: [71, 72]
# len to explore 4
# good_neighbour: [70, 71]
# len to explore 4
# good_neighbour: [70, 72]
# len to explore 4
# good_neighbour: [70, 73]
# len to explore 4
# good_neighbour: [69, 72]
# len to explore 4
# good_neighbour: [69, 73]
# len to explore 4
# good_neighbour: [70, 74]
# good_neighbour: [69, 74]
# len to explore 5
# good_neighbour: [68, 73]
# len to explore 5
# good_neighbour: [68, 74]
# len to explore 5
# good_neighbour: [69, 75]
# len to explore 5
# good_neighbour: [68, 75]
# len to explore 5
# len to explore 4
# good_neighbour: [67, 75]
# len to explore 4
# good_neighbour: [69, 76]
# good_neighbour: [68, 76]
# len to explore 5
# good_neighbour: [67, 76]
# len to explore 5
# len to explore 4
# good_neighbour: [68, 77]
# len to explore 4
# good_neighbour: [67, 77]
# len to explore 4
# len to explore 3
# good_neighbour: [68, 78]
# good_neighbour: [67, 78]
# len to explore 4
# len to explore 3
# good_neighbour: [68, 79]
# good_neighbour: [67, 79]
# len to explore 4
# good_neighbour: [66, 79]
# len to explore 4
# good_neighbour: [67, 80]
# len to explore 4
# good_neighbour: [66, 80]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 81]
# good_neighbour: [66, 81]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 82]
# good_neighbour: [66, 82]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 83]
# good_neighbour: [66, 83]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 84]
# good_neighbour: [66, 84]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 85]
# good_neighbour: [66, 85]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 86]
# good_neighbour: [66, 86]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 87]
# good_neighbour: [66, 87]
# len to explore 4
# len to explore 3
# good_neighbour: [67, 88]
# len to explore 3
# good_neighbour: [68, 89]
# len to explore 3
# good_neighbour: [67, 89]
# len to explore 3
# good_neighbour: [68, 90]
# good_neighbour: [67, 90]
# len to explore 4
# len to explore 3
# good_neighbour: [68, 91]
# good_neighbour: [67, 91]
# len to explore 4
# len to explore 3
# good_neighbour: [68, 92]
# good_neighbour: [67, 92]
# len to explore 4
# good_neighbour: [69, 93]
# len to explore 4
# good_neighbour: [68, 93]
# len to explore 4
# good_neighbour: [69, 94]
# len to explore 4
# good_neighbour: [68, 94]
# len to explore 4
# len to explore 3
# good_neighbour: [69, 95]
# good_neighbour: [68, 95]
# len to explore 4
# good_neighbour: [70, 96]
# len to explore 4
# good_neighbour: [69, 96]
# len to explore 4
# good_neighbour: [70, 97]
# len to explore 4
# good_neighbour: [69, 97]
# len to explore 4
# len to explore 3
# good_neighbour: [70, 98]
# len to explore 3
# good_neighbour: [71, 99]
# len to explore 3
# good_neighbour: [70, 99]
# len to explore 3
# good_neighbour: [71, 100]
# len to explore 3
# good_neighbour: [72, 101]
# len to explore 3
# good_neighbour: [71, 101]
# len to explore 3
# good_neighbour: [72, 102]
# len to explore 3
# good_neighbour: [73, 103]
# len to explore 3
# good_neighbour: [72, 103]
# good_neighbour: [74, 104]
# len to explore 4
# good_neighbour: [73, 104]
# len to explore 4
# good_neighbour: [74, 105]
# len to explore 4
# good_neighbour: [73, 105]
# len to explore 4
# good_neighbour: [75, 106]
# len to explore 4
# good_neighbour: [74, 106]
# good_neighbour: [76, 107]
# len to explore 5
# good_neighbour: [75, 107]
# len to explore 5
# len to explore 4
# good_neighbour: [76, 108]
# len to explore 4
# good_neighbour: [75, 108]
# len to explore 4
# good_neighbour: [77, 109]
# len to explore 4
# good_neighbour: [76, 109]
# good_neighbour: [78, 110]
# len to explore 5
# good_neighbour: [77, 110]
# len to explore 5
# good_neighbour: [79, 111]
# len to explore 5
# good_neighbour: [78, 111]
# len to explore 5
# len to explore 4
# good_neighbour: [79, 112]
# len to explore 4
# len to explore 3
# good_neighbour: [80, 113]
# len to explore 3
# good_neighbour: [79, 113]
# good_neighbour: [81, 114]
# len to explore 4
# good_neighbour: [80, 114]
# good_neighbour: [82, 115]
# len to explore 5
# good_neighbour: [81, 115]
# len to explore 5
# good_neighbour: [83, 116]
# len to explore 5
# good_neighbour: [82, 116]
# len to explore 5
# good_neighbour: [84, 117]
# len to explore 5
# good_neighbour: [83, 117]
# len to explore 5
# good_neighbour: [85, 118]
# len to explore 5
# good_neighbour: [84, 118]
# len to explore 5
# good_neighbour: [86, 119]
# len to explore 5
# good_neighbour: [85, 119]
# len to explore 5
# good_neighbour: [87, 120]
# len to explore 5
# good_neighbour: [86, 120]
# len to explore 5
# good_neighbour: [88, 121]
# len to explore 5
# good_neighbour: [87, 121]
# len to explore 5
# good_neighbour: [89, 122]
# len to explore 5
# len to explore 4
# good_neighbour: [89, 121]
# good_neighbour: [90, 123]
# len to explore 5
# len to explore 4
# good_neighbour: [90, 122]
# good_neighbour: [91, 124]
# len to explore 5
# good_neighbour: [91, 123]
# len to explore 5
# good_neighbour: [92, 125]
# len to explore 5
# good_neighbour: [92, 124]
# len to explore 5
# good_neighbour: [93, 124]
# len to explore 5
# good_neighbour: [93, 125]
# len to explore 5
# good_neighbour: [94, 125]
# len to explore 5
# good_neighbour: [94, 126]
# len to explore 5
# good_neighbour: [95, 126]
# len to explore 5
# good_neighbour: [95, 127]
# len to explore 5
# good_neighbour: [96, 127]
# len to explore 5
# good_neighbour: [96, 126]
# len to explore 5
# good_neighbour: [97, 128]
# len to explore 5
# good_neighbour: [97, 127]
# len to explore 5
# len to explore 4
# good_neighbour: [98, 128]
# len to explore 4
# good_neighbour: [99, 128]
# len to explore 4
# good_neighbour: [99, 129]
# len to explore 4
# len to explore 3
# len to explore 2
# len to explore 1
# extended_solutions: [[98, 70], [99, 70], [97, 70], [97, 69], [99, 71], [98, 70], [100, 71], [101, 72], [96, 70], [96, 69], [95, 68], [101, 71], [102, 72], [103, 72], [95, 69], [94, 68], [94, 69], [103, 73], [104, 74], [104, 73], [105, 74], [93, 68], [93, 69], [92, 67], [105, 73], [106, 74], [106, 75], [107, 76], [92, 68], [91, 67], [91, 68], [107, 75], [108, 76], [108, 75], [109, 76], [90, 67], [90, 68], [109, 77], [110, 78], [110, 77], [111, 78], [89, 67], [89, 68], [111, 79], [112, 79], [113, 80], [88, 67], [87, 66], [113, 79], [114, 81], [114, 80], [115, 82], [87, 67], [86, 66], [86, 67], [115, 81], [116, 83], [116, 82], [117, 84], [85, 66], [85, 67], [117, 83], [118, 85], [118, 84], [119, 86], [84, 66], [84, 67], [119, 85], [120, 87], [120, 86], [121, 88], [83, 66], [83, 67], [121, 87], [122, 89], [121, 89], [123, 90], [82, 66], [82, 67], [122, 90], [124, 91], [123, 91], [125, 92], [81, 66], [81, 67], [124, 92], [125, 93], [124, 93], [80, 66], [80, 67], [126, 94], [125, 94], [127, 95], [126, 95], [79, 66], [79, 67], [79, 68], [127, 96], [126, 96], [128, 97], [78, 67], [78, 68], [127, 97], [128, 98], [77, 67], [77, 68], [129, 99], [128, 99], [76, 67], [76, 68], [76, 69], [75, 67], [75, 68], [75, 69], [74, 68], [74, 69], [74, 70], [73, 68], [73, 69], [73, 70], [72, 69], [72, 70], [72, 71], [71, 70], [71, 71], [71, 72], [70, 71], [70, 72], [70, 73], [69, 72], [69, 73], [70, 74], [69, 74], [68, 73], [68, 74], [69, 75], [68, 75], [67, 75], [69, 76], [68, 76], [67, 76], [68, 77], [67, 77], [68, 78], [67, 78], [68, 79], [67, 79], [66, 79], [67, 80], [66, 80], [67, 81], [66, 81], [67, 82], [66, 82], [67, 83], [66, 83], [67, 84], [66, 84], [67, 85], [66, 85], [67, 86], [66, 86], [67, 87], [66, 87], [67, 88], [68, 89], [67, 89], [68, 90], [67, 90], [68, 91], [67, 91], [68, 92], [67, 92], [69, 93], [68, 93], [69, 94], [68, 94], [69, 95], [68, 95], [70, 96], [69, 96], [70, 97], [69, 97], [70, 98], [71, 99], [70, 99], [71, 100], [72, 101], [71, 101], [72, 102], [73, 103], [72, 103], [74, 104], [73, 104], [74, 105], [73, 105], [75, 106], [74, 106], [76, 107], [75, 107], [76, 108], [75, 108], [77, 109], [76, 109], [78, 110], [77, 110], [79, 111], [78, 111], [79, 112], [80, 113], [79, 113], [81, 114], [80, 114], [82, 115], [81, 115], [83, 116], [82, 116], [84, 117], [83, 117], [85, 118], [84, 118], [86, 119], [85, 119], [87, 120], [86, 120], [88, 121], [87, 121], [89, 122], [89, 121], [90, 123], [90, 122], [91, 124], [91, 123], [92, 125], [92, 124], [93, 124], [93, 125], [94, 125], [94, 126], [95, 126], [95, 127], [96, 127], [96, 126], [97, 128], [97, 127], [98, 128], [99, 128], [99, 129]]

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(total_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
# /var/folders/3_/hxxz6cjj6k92q_tqrvht1tf80000gn/T/ipykernel_68560/1149142918.py:2: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
#final selection
f_selct =[]
v_select =[]
minim = 8.76763323079435e-05

for i in range(len(total_solutions)):
    s = total_solutions[i]
    v = total_values[i]
    if v<=minim:
        is not in f_select:
            f_select.append(s)
            v_select.append(v)
    
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zlim(-1.01, 1.01)

x,y,z = xyz_gen(total_solutions, fit_function)
ax.scatter(x,y,z , c='b', marker='^')
# Out:
#   Cell In [19], line 4
#     for s in to
#                ^
# SyntaxError: invalid syntax
